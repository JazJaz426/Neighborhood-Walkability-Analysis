# %% [markdown]
# ### Open all the provided csv files and get connected to the server

# %%
import csv
import pprint
## open all the provided csv files
data_StatisticalArea = list(csv.DictReader(open('StatisticalAreas.csv')))
data_Neighbourhoods = list(csv.DictReader(open('Neighbourhoods.csv')))
data_CensusStats = list(csv.DictReader(open('CensusStats.csv')))
data_BusinessStats = list(csv.DictReader(open('BusinessStats.csv')))
data_Pods = list(csv.DictReader(open('CarSharingPods.csv')))

# %%
import psycopg2
##connect to the server
def pgconnect():
    YOUR_UNIKEY = 'jlin0701'
    YOUR_PW     = '470345744'
    try: 
        conn = psycopg2.connect(host='soit-db-pro-1.ucc.usyd.edu.au',database='y18s1d2001_jlin0701',user='y18s1d2001_jlin0701',password='470345744')
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return conn

# %%
def pgexec( conn, sqlcmd, args, msg, silent=False ):
   """ utility function to execute some SQL statement
       can take optional arguments to fill in (dictionary)
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
               cur.execute(sqlcmd)
            else:
               cur.execute(sqlcmd, args)
            if silent == False: 
                print("success: " + msg)
            retval = True
         except Exception as e:
            if silent == False: 
                print("db error: ")
                print(e)
   return retval

# %%
def pgquery( conn, sqlcmd, args, silent=False ):
   """ utility function to execute some SQL query statement
       can take optional arguments to fill in (dictionary)
       will print out on screen the result set of the query
       error and transaction handling built-in """
   retval = False
   with conn:
      with conn.cursor() as cur:
         try:
            if args is None:
                cur.execute(sqlcmd)
            else:
                cur.execute(sqlcmd, args)
            if silent == False:
                for record in cur:
                    print(record)
            retval = True
         except Exception as e:
            if silent == False:
                print("db read error: ")
                print(e)
   return retval

# %% [markdown]
# ### Data Cleaning and Create Table for StatisticalArea, CensusStats and BusinessStats

# %%
## Data Cleaning

import numpy as np
DEFAULT_VALUE = np.nan

def clean(data, column_key, convert_function, default_value):
    special_values= {np.nan:0, '':0}
    for row in data:
        old_value = row[column_key]
        new_value = default_value
        try:
            if old_value in special_values.keys():
                new_value = special_values[old_value]
            else:
                new_value = convert_function(old_value)
        except (ValueError, TypeError):
            print('Replacing {} with {} in column {}'.format(row[column_key], new_value, column_key))
        row[column_key] = new_value

# %%
# clean the string data in StatisticalArea
# strip any leading or trailing spaces from the 'StatisticalArea' values
clean(data_StatisticalArea, 'area_name', str.strip, DEFAULT_VALUE)

# the following converts the three StatisticalArea columns to float or int values - or NaN
clean(data_StatisticalArea, 'area_id', int, DEFAULT_VALUE)
clean(data_StatisticalArea, 'parent_area_id', int, DEFAULT_VALUE)

# %%
# ready to create the StatisticalArea Table
conn = pgconnect()

pgexec (conn, "DROP TABLE IF EXISTS StatisticalArea",None,"Reset Table StatisticalArea")

StatisticalArea_schema = """CREATE TABLE StatisticalArea(
                          area_id INT NOT NULL,
                          area_name VARCHAR(50) NOT NULL,
                          parent_area_id  INT NOT NULL,
                          PRIMARY KEY (area_id)
                        )"""
pgexec (conn, StatisticalArea_schema, None, "Create Table StatisticalArea")


# Load the values into the table(sql) from data_StatisticalArea
insert_stmt = """INSERT INTO StatisticalArea(area_id,area_name,parent_area_id) VALUES (%(area_id)s,%(area_name)s,%(parent_area_id)s)"""
for row in data_StatisticalArea:
    pgexec (conn,insert_stmt,row,"row inserted")
# Out:
# connected
# success: Reset Table StatisticalArea
# success: Create Table StatisticalArea
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %%
# the following converts the three CensusStats columns to float or int values - or NaN
clean(data_CensusStats, 'area_id', int, DEFAULT_VALUE)
clean(data_CensusStats, 'median_annual_household_income', float, DEFAULT_VALUE)
clean(data_CensusStats, 'avg_monthly_rent', int, DEFAULT_VALUE)

# %%
# the following converts the 7 BusinessStats columns to float  values - or NaN
clean(data_BusinessStats, 'area_id', int, DEFAULT_VALUE)
clean(data_BusinessStats, 'num_businesses', float, DEFAULT_VALUE)
clean(data_BusinessStats, 'retail_trade', int, DEFAULT_VALUE)
clean(data_BusinessStats, 'accommodation_and_food_services', int, DEFAULT_VALUE)
clean(data_BusinessStats, 'health_care_and_social_assistance', int, DEFAULT_VALUE)
clean(data_BusinessStats, 'education_and_training', int, DEFAULT_VALUE)
clean(data_BusinessStats, 'arts_and_recreation_services', int, DEFAULT_VALUE)

# %%
# Create the BusinessStats table
pgexec(conn, "DROP TABLE IF EXISTS BusinessStats",None,"Reset Table BusinessStats")

BusinessStats_schema = """CREATE TABLE BusinessStats(
                          area_id INT NOT NULL,
                          n_businesses INT,
                          retail_trade INT,
                          accomodationFoodServices INT,
                          healthyCare_SocialAssistance INT,
                          education INT,
                          arts INT,
                          PRIMARY KEY (area_id)
                        );"""

pgexec(conn, BusinessStats_schema, None, "Create Table BusinessStats")

# Load the values from data_BusinessStats into the BussinessStats table
insert_stmt = """INSERT INTO BusinessStats(area_id,n_businesses,retail_trade,accomodationFoodServices,healthyCare_SocialAssistance,education,arts) 
            VALUES(%(area_id)s,%(num_businesses)s,%(retail_trade)s,%(accommodation_and_food_services)s,%(health_care_and_social_assistance)s,%(education_and_training)s,%(arts_and_recreation_services)s)"""
for row in data_BusinessStats:
    pgexec (conn,insert_stmt,row,"row inserted")
# Out:
# success: Reset Table BusinessStats
# success: Create Table BusinessStats
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %% [markdown]
# # Get the Connections between the CarPodsSharing and Neighbourhoods

# %%
## Scrapping address data from Google API

import time
def get_boundary(address):
    try:
        base_url = 'http://maps.googleapis.com/maps/api/geocode/json'
        my_params= {'address': address,'language':'en'}
        response = requests.get(base_url, params = my_params)
        results      = response.json()['results']
        if 'bounds' in results[0]['geometry']:
            nhood_bounds = results[0]['geometry']['bounds']
            return nhood_bounds
        else:
            return results[0]['geometry']['viewport']
    except IndexError as e:
        time.sleep(10)
        get_boundary(address)
    except KeyError as k:
        time.sleep(10)
        get_boundary(address)

# %%
import requests
import json

## Try to get the latitude and longitude for every Neighbourhoods via Google API
## and store the values of latitude and longitude in the data_Neighbourhoods 
for r in data_Neighbourhoods:
    address = r['area_name']
    address= address.strip().replace('\n', '')
    result = get_boundary(address)
    if result is not None:
        northeast_lat = float(result['northeast']['lat'])
        northeast_lng = float(result['northeast']['lng'])
        southwest_lat = float(result['southwest']['lat'])
        southwest_lng = float(result['southwest']['lng'])
        r.update({'ne_lat':northeast_lat})
        r.update({'ne_lng':northeast_lng})
        r.update({'sw_lat':southwest_lat})
        r.update({'sw_lng':southwest_lat})
        
    else:
        # Since the address is not detailed, give it a more specifed address
        address = address+" - Australia"
        result = get_boundary(address)
        if result is not None:
            northeast_lat = float(result['northeast']['lat'])
            northeast_lng = float(result['northeast']['lng'])
            southwest_lat = float(result['southwest']['lat'])
            southwest_lng = float(result['southwest']['lng'])
            r.update({'ne_lat':northeast_lat})
            r.update({'ne_lng':northeast_lng})
            r.update({'sw_lat':southwest_lat})
            r.update({'sw_lng':southwest_lat})
            t = ((southwest_lat, southwest_lng),(northeast_lat, northeast_lng))
        else:
            result = get_boundary(address)
            northeast_lat = float(result['northeast']['lat'])
            northeast_lng = float(result['northeast']['lng'])
            southwest_lat = float(result['southwest']['lat'])
            southwest_lng = float(result['southwest']['lng'])
            r.update({'ne_lat':northeast_lat})
            r.update({'ne_lng':northeast_lng})
            r.update({'sw_lat':southwest_lat})
            r.update({'sw_lng':southwest_lat})
            t = ((southwest_lat, southwest_lng),(northeast_lat, northeast_lng))

# %%
for row in data_Neighbourhoods:
    southwest_lat = row['sw_lat']
    southwest_lng = row['sw_lng']
    northeast_lat = row['ne_lat']
    northeast_lng = row['ne_lng']
    t = ((southwest_lat, southwest_lng),(northeast_lat, northeast_lng))
    row.update({'boundary':t})

# %%
# Check what heighbourhood the car pod is inside
# Copy the area_id of that neighbourhood into the data_Pods
for row in data_Pods:
    lat = float(row['latitude'])
    lng = float(row['longitude'])
    for r in data_Neighbourhoods:
        northeast_lat = r['ne_lat']
        northeast_lng = r['ne_lng']
        southwest_lat = r['sw_lat']
        southwest_lat = r['sw_lng']

        if lat >= southwest_lat and lat <= northeast_lat and lng <= northeast_lng and lng >= southwest_lng:
            row.update({'area_id':r['area_id']})

# %%
# Count how many car pods there are in each neighbourhood
# Store the number of car pods in that neighbourhoods into data_Neigbourhoods
for row in data_Neighbourhoods:
    area_id = row['area_id']
    count = 0
    for r in data_Pods:
        if 'area_id' in r:
            if area_id == r['area_id']:
                count += 1
            
    row.update({"num_pods" : count})

# %% [markdown]
# ### Create the Pod table and load the data including the area_id into the table

# %%
# clean the data with string type in Pods
# strip any leading or trailing spaces from the 'Neighbourhoods' values
clean(data_Pods, 'name', str.strip, DEFAULT_VALUE)
clean(data_Pods, 'description', str.strip, DEFAULT_VALUE)


# the following converts the 4 Pods columns to float or int values - or NaN
clean(data_Pods, 'pod_id', int, DEFAULT_VALUE)
clean(data_Pods, 'num_cars', int, DEFAULT_VALUE)
clean(data_Pods, 'latitude', float, DEFAULT_VALUE)
clean(data_Pods, 'longitude', float, DEFAULT_VALUE)

# %%
# Create the Pods table
pgexec(conn, "DROP TABLE IF EXISTS Pods",None,"Reset Table Pods")

Pods_schema ="""CREATE TABLE Pods(
                  pod_id INT NOT NULL,
                  name VARCHAR(500) NOT NULL,
                  n_cars INT,
                  description VARCHAR(5000),
                  area_id INT,
                  location geometry,
                  PRIMARY KEY(pod_id)
                );"""

pgexec(conn, Pods_schema, None, "Create Table Pods")

# Loading data into the Pods table
insert_stmt = """INSERT INTO Pods(pod_id,name,n_cars,description, area_id, location) 
                VALUES(%(pod_id)s,%(name)s,%(num_cars)s,%(description)s, %(area_id)s, ST_MakePoint(%(latitude)s, %(longitude)s))"""
for row in data_Pods:
    pgexec (conn,insert_stmt,row,"row inserted")
# Out:
# success: Reset Table Pods
# success: Create Table Pods
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %% [markdown]
# ### find the train station(bonus)

# %%
# Extract the data of the list of train stations from html
import requests
from bs4 import BeautifulSoup
import json
import csv

page_html = requests.get("https://en.wikipedia.org/wiki/List_of_Sydney_Trains_railway_stations").text
page_content = BeautifulSoup(page_html, 'html5lib')
tables = page_content.find(id = 'bodyContent').find_all("table", {"class": "wikitable sortable"})

try:
    station_names = []
    data_table = page_content.find_all("tr")
    for row in data_table[2:]:
        station_name = row.a["href"].replace("/wiki/","").replace(",_Sydney","")
        station_names.append(station_name)
except TypeError as te:
    print(te)
# Out:
# 'NoneType' object is not subscriptable

# %%
#write the data extracted from the web into the Stations.csv file
with open("Stations.csv","w") as output:
    fieldnames = ['station_id', 'stations']
    writer = csv.DictWriter(output, fieldnames=fieldnames)
    writer.writeheader()
    count = 0
    for name in station_names:
        writer.writerow({ 'station_id': count, 'stations': name})
        count += 1

# %%
def get_geolocation(address):
    result = get_boundary(address)
    if result is not None:
        return result
    if result is None:
        get_geolocation(address)

# %%
# for every station in the csv file, get the boundary of each train station
data_Stations = list(csv.DictReader(open('Stations.csv')))
for r in data_Stations:
    address = r['stations']
    address= address.strip().replace('\n', '')
    try:
        result = get_geolocation(address)
        northeast_lat = float(result['northeast']['lat'])
        northeast_lng = float(result['northeast']['lng'])
        southwest_lat = float(result['southwest']['lat'])
        southwest_lng = float(result['southwest']['lng'])
        r.update({'ne_lat':northeast_lat})
        r.update({'ne_lng':northeast_lng})
        r.update({'sw_lat':southwest_lat})
        r.update({'sw_lng':southwest_lat})

    except TypeError as te:
        try:
            result = get_geolocation(address)
            northeast_lat = float(result['northeast']['lat'])
            northeast_lng = float(result['northeast']['lng'])
            southwest_lat = float(result['southwest']['lat'])
            southwest_lng = float(result['southwest']['lng'])
            r.update({'ne_lat':northeast_lat})
            r.update({'ne_lng':northeast_lng})
            r.update({'sw_lat':southwest_lat})
            r.update({'sw_lng':southwest_lat})
        except TypeError as te2:
            result = get_geolocation(address)
            northeast_lat = float(result['northeast']['lat'])
            northeast_lng = float(result['northeast']['lng'])
            southwest_lat = float(result['southwest']['lat'])
            southwest_lng = float(result['southwest']['lng'])
            r.update({'ne_lat':northeast_lat})
            r.update({'ne_lng':northeast_lng})
            r.update({'sw_lat':southwest_lat})
            r.update({'sw_lng':southwest_lat})

# %%
# loop throgh the stations list and try to find which neighbourhood contains that train station
# store the area_id of the neighbourhood into the data_Stations
for row in data_Stations:
    ne_lat = float(row['ne_lat'])
    ne_lng = float(row['ne_lng'])
    sw_lat = float(row['sw_lat'])
    sw_lng = float(row['sw_lng'])
    for r in data_Neighbourhoods:
        northeast_lat = r['ne_lat']
        northeast_lng = r['ne_lng']
        southwest_lat = r['sw_lat']
        southwest_lng = r['sw_lng']

        if southwest_lat <= ne_lat and ne_lat <= northeast_lat: 
            if southwest_lng <= ne_lng and ne_lng <= northeast_lng:
                row.update({'area_id':r['area_id']})
        elif southwest_lat <= sw_lat and sw_lat <= northeast_lat: 
            if southwest_lng <= sw_lng and sw_lng <= northeast_lng:
                row.update({'area_id':r['area_id']})

# %%
# clean the data with string type in TrainStations
# strip any leading or trailing spaces from the 'TrainStations' values
clean(data_Stations, 'stations', str.strip, DEFAULT_VALUE)

# the following converts the 7 Neighbourhoods columns to float or int values - or NaN
clean(data_Stations, 'station_id', float, DEFAULT_VALUE)
clean(data_Stations, 'ne_lat', float, DEFAULT_VALUE)
clean(data_Stations, 'ne_lng', float, DEFAULT_VALUE)
clean(data_Stations, 'sw_lat', float, DEFAULT_VALUE)
clean(data_Stations, 'sw_lng', float, DEFAULT_VALUE)
try:
    clean(data_Stations, 'area_id', int, DEFAULT_VALUE)
except KeyError as ke:
    print("no corresponding area_id")
# Out:
# no corresponding area_id

# %%
# Create the TrainStations table

pgexec(conn, "DROP TABLE IF EXISTS TrainStations",None,"Reset Table TrainStations")

TrainStations_schema = """CREATE TABLE TrainStations(
                            station_id INT NOT NULL,
                            station_name VARCHAR(50) NOT NULL, 
                            area_id INT, 
                            sw_location geometry,
                            ne_location geometry,
                            PRIMARY KEY (station_id))
                            ;
                        """

pgexec (conn, TrainStations_schema, None, "Create Table TrainStations")

# load the data into the Neighbourhoods table
insert_stmt = """INSERT INTO TrainStations(station_id, station_name,area_id, sw_location, ne_location) 
                VALUES (%(station_id)s, %(stations)s,%(area_id)s, ST_MakePoint(%(sw_lat)s,%(sw_lng)s), ST_MakePoint(%(ne_lat)s, %(ne_lng)s))"""
for row in data_Stations:
    pgexec(conn,insert_stmt,row,"row inserted")
# Out:
# success: Reset Table TrainStations
# success: Create Table TrainStations
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# db error:
# 'area_id'
# db error:
# 'area_id'
# db error:
# 'area_id'
# db error:
# 'area_id'
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# db error:
# 'area_id'
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted
# db error:
# 'area_id'
# success: row inserted
# success: row inserted

# %%
# count how many train stations in that neighbourhood
# and store the number of train stations for each neighbourhood in data_Neighbourhood
for row in data_Neighbourhoods:
    area_id = row['area_id']
    count = 0
    for r in data_Stations:
        if 'area_id' in r:
            if area_id == r['area_id']:
                count += 1
            
    row.update({"num_stations" : count})

# %% [markdown]
# ### Crteate the Neighbourhoods table and load the data from data_Neighbourhoods

# %%
# clean the data with string type in Neighbourhoods
# strip any leading or trailing spaces from the 'Neighbourhoods' values
clean(data_Neighbourhoods, 'area_name', str.strip, DEFAULT_VALUE)

# the following converts the 7 Neighbourhoods columns to float or int values - or NaN
clean(data_Neighbourhoods, 'area_id', int, DEFAULT_VALUE)
clean(data_Neighbourhoods, 'land_area', float, DEFAULT_VALUE)
clean(data_Neighbourhoods, 'population', int, DEFAULT_VALUE)
clean(data_Neighbourhoods, 'number_of_dwellings', int, DEFAULT_VALUE)
clean(data_Neighbourhoods, 'number_of_businesses', int, DEFAULT_VALUE)
clean(data_Neighbourhoods, 'num_pods', int, DEFAULT_VALUE)
clean(data_Neighbourhoods, 'num_stations', int, DEFAULT_VALUE)

# %%
# Create the Neighbourhoods table
pgexec(conn, "DROP TABLE IF EXISTS Neighbourhoods",None,"Reset Table Neighbourhoods")

Neighbourhoods_schema = """CREATE TABLE Neighbourhoods(
                            area_id INT NOT NULL, 
                            area_name VARCHAR(50) NOT NULL, 
                            land_area FLOAT NOT NULL, 
                            population INT, 
                            n_dwellings INT, 
                            n_businesses INT,
                            num_pods INT,
                            num_stations INT,
                            boundary geometry NOT NULL,
                            PRIMARY KEY (area_id));
                        """

pgexec (conn, Neighbourhoods_schema, None, "Create Table Neighbourhoods")

# load the data into the Neighbourhoods table
insert_stmt = """INSERT INTO Neighbourhoods(area_id,area_name,land_area,population, n_dwellings,n_businesses, num_pods, num_stations, boundary) 
                VALUES (%(area_id)s,%(area_name)s,%(land_area)s,%(population)s,%(number_of_dwellings)s,%(number_of_businesses)s, %(num_pods)s, %(num_stations)s, ST_MakeBox2D(ST_MakePoint(%(sw_lat)s, %(sw_lng)s), ST_MakePoint(%(ne_lat)s, %(ne_lng)s)))"""
for row in data_Neighbourhoods:
    pgexec(conn,insert_stmt,row,"row inserted")
# Out:
# success: Reset Table Neighbourhoods
# success: Create Table Neighbourhoods
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %% [markdown]
# ## Create View

# %%
# Join the Neighbourhoods, BusinessStats, StatisticalArea, CensusStats, Pods and TrainStations table
join_all = """
            CREATE VIEW spatial_join_view
            AS
            SELECT * 
            FROM Neighbourhoods N
            natural join StatisticalArea SA
            natural join CensusStats CS
            natural join BusinessStats BS
            natural join Pods p
            natural join TrainStations TS
            where ST_Contains(N.boundary, p.location) and (ST_Contains(N.boundary, TS.ne_location) or ST_Contains(N.boundary, TS.sw_location))
            ;
        """
pgexec(conn, join_all, None, "join successfully")
# Out:
# success: join successfully
# True

# %%
#Show the created view
import pandas
data_spatial = pandas.read_sql_query("SELECT * FROM spatial_join_view", conn)
data_spatial
# Out:
#        area_id  n_businesses         area_name  land_area  population  \
# 0    118011347          1384         Woollahra      128.1        8246
# 1    118011347          1384         Woollahra      128.1        8246
# 2    118021570          1402  Randwick - South      337.3       14238
# 3    118021570          1402  Randwick - South      337.3       14238
# 4    118021570          1402  Randwick - South      337.3       14238
# 5    118021570          1402  Randwick - South      337.3       14238
# 6    118011347          1384         Woollahra      128.1        8246
# 7    118011347          1384         Woollahra      128.1        8246
# 8    118021570          1402  Randwick - South      337.3       14238
# 9    118021570          1402  Randwick - South      337.3       14238
# 10   118021570          1402  Randwick - South      337.3       14238
# 11   118021570          1402  Randwick - South      337.3       14238
# 12   118011347          1384         Woollahra      128.1        8246
# 13   118011347          1384         Woollahra      128.1        8246
# 14   121041415          4227            Mosman      865.0       30465
# 15   118011347          1384         Woollahra      128.1        8246
# 16   118011347          1384         Woollahra      128.1        8246
# 17   118011347          1384         Woollahra      128.1        8246
# 18   118011347          1384         Woollahra      128.1        8246
# 19   118011347          1384         Woollahra      128.1        8246
# 20   118011347          1384         Woollahra      128.1        8246
# 21   118011347          1384         Woollahra      128.1        8246
# 22   118011347          1384         Woollahra      128.1        8246
# 23   118011347          1384         Woollahra      128.1        8246
# 24   118011347          1384         Woollahra      128.1        8246
# 25   118021570          1402  Randwick - South      337.3       14238
# 26   118021570          1402  Randwick - South      337.3       14238
# 27   118021570          1402  Randwick - South      337.3       14238
# 28   118021570          1402  Randwick - South      337.3       14238
# 29   118021570          1402  Randwick - South      337.3       14238
# ..         ...           ...               ...        ...         ...
# 642  118021570          1402  Randwick - South      337.3       14238
# 643  118021570          1402  Randwick - South      337.3       14238
# 644  118021570          1402  Randwick - South      337.3       14238
# 645  118021570          1402  Randwick - South      337.3       14238
# 646  118011347          1384         Woollahra      128.1        8246
# 647  118011347          1384         Woollahra      128.1        8246
# 648  118011347          1384         Woollahra      128.1        8246
# 649  118011347          1384         Woollahra      128.1        8246
# 650  118021570          1402  Randwick - South      337.3       14238
# 651  118021570          1402  Randwick - South      337.3       14238
# 652  118021570          1402  Randwick - South      337.3       14238
# 653  118021570          1402  Randwick - South      337.3       14238
# 654  118011347          1384         Woollahra      128.1        8246
# 655  118011347          1384         Woollahra      128.1        8246
# 656  118011347          1384         Woollahra      128.1        8246
# 657  118011347          1384         Woollahra      128.1        8246
# 658  118021570          1402  Randwick - South      337.3       14238
# 659  118021570          1402  Randwick - South      337.3       14238
# 660  118021570          1402  Randwick - South      337.3       14238
# 661  118021570          1402  Randwick - South      337.3       14238
# 662  118011347          1384         Woollahra      128.1        8246
# 663  118011347          1384         Woollahra      128.1        8246
# 664  118011347          1384         Woollahra      128.1        8246
# 665  118011347          1384         Woollahra      128.1        8246
# 666  118021570          1402  Randwick - South      337.3       14238
# 667  118021570          1402  Randwick - South      337.3       14238
# 668  118021570          1402  Randwick - South      337.3       14238
# 669  118021570          1402  Randwick - South      337.3       14238
# 670  118011347          1384         Woollahra      128.1        8246
# 671  118011347          1384         Woollahra      128.1        8246
#
#      n_dwellings  num_pods  num_stations  \
# 0           1960       213             2
# 1           1960       213             2
# 2           3922        46             4
# 3           3922        46             4
# 4           3922        46             4
# 5           3922        46             4
# 6           1960       213             2
# 7           1960       213             2
# 8           3922        46             4
# 9           3922        46             4
# 10          3922        46             4
# 11          3922        46             4
# 12          1960       213             2
# 13          1960       213             2
# 14          9651        37             1
# 15          1960       213             2
# 16          1960       213             2
# 17          1960       213             2
# 18          1960       213             2
# 19          1960       213             2
# 20          1960       213             2
# 21          1960       213             2
# 22          1960       213             2
# 23          1960       213             2
# 24          1960       213             2
# 25          3922        46             4
# 26          3922        46             4
# 27          3922        46             4
# 28          3922        46             4
# 29          3922        46             4
# ..           ...       ...           ...
# 642         3922        46             4
# 643         3922        46             4
# 644         3922        46             4
# 645         3922        46             4
# 646         1960       213             2
# 647         1960       213             2
# 648         1960       213             2
# 649         1960       213             2
# 650         3922        46             4
# 651         3922        46             4
# 652         3922        46             4
# 653         3922        46             4
# 654         1960       213             2
# 655         1960       213             2
# 656         1960       213             2
# 657         1960       213             2
# 658         3922        46             4
# 659         3922        46             4
# 660         3922        46             4
# 661         3922        46             4
# 662         1960       213             2
# 663         1960       213             2
# 664         1960       213             2
# 665         1960       213             2
# 666         3922        46             4
# 667         3922        46             4
# 668         3922        46             4
# 669         3922        46             4
# 670         1960       213             2
# 671         1960       213             2
#
#                                               boundary  parent_area_id  \
# 0    010300000001000000050000009CBF098508F240C09CBF...           11801
# 1    010300000001000000050000009CBF098508F240C09CBF...           11801
# 2    010300000001000000050000007288B83995F740C07288...           11802
# 3    010300000001000000050000007288B83995F740C07288...           11802
# 4    010300000001000000050000007288B83995F740C07288...           11802
# 5    010300000001000000050000007288B83995F740C07288...           11802
# 6    010300000001000000050000009CBF098508F240C09CBF...           11801
# 7    010300000001000000050000009CBF098508F240C09CBF...           11801
# 8    010300000001000000050000007288B83995F740C07288...           11802
# 9    010300000001000000050000007288B83995F740C07288...           11802
# 10   010300000001000000050000007288B83995F740C07288...           11802
# 11   010300000001000000050000007288B83995F740C07288...           11802
# 12   010300000001000000050000009CBF098508F240C09CBF...           11801
# 13   010300000001000000050000009CBF098508F240C09CBF...           11801
# 14   01030000000100000005000000B32781CD39ED40C0B327...           12104
# 15   010300000001000000050000009CBF098508F240C09CBF...           11801
# 16   010300000001000000050000009CBF098508F240C09CBF...           11801
# 17   010300000001000000050000009CBF098508F240C09CBF...           11801
# 18   010300000001000000050000009CBF098508F240C09CBF...           11801
# 19   010300000001000000050000009CBF098508F240C09CBF...           11801
# 20   010300000001000000050000009CBF098508F240C09CBF...           11801
# 21   010300000001000000050000009CBF098508F240C09CBF...           11801
# 22   010300000001000000050000009CBF098508F240C09CBF...           11801
# 23   010300000001000000050000009CBF098508F240C09CBF...           11801
# 24   010300000001000000050000009CBF098508F240C09CBF...           11801
# 25   010300000001000000050000007288B83995F740C07288...           11802
# 26   010300000001000000050000007288B83995F740C07288...           11802
# 27   010300000001000000050000007288B83995F740C07288...           11802
# 28   010300000001000000050000007288B83995F740C07288...           11802
# 29   010300000001000000050000007288B83995F740C07288...           11802
# ..                                                 ...             ...
# 642  010300000001000000050000007288B83995F740C07288...           11802
# 643  010300000001000000050000007288B83995F740C07288...           11802
# 644  010300000001000000050000007288B83995F740C07288...           11802
# 645  010300000001000000050000007288B83995F740C07288...           11802
# 646  010300000001000000050000009CBF098508F240C09CBF...           11801
# 647  010300000001000000050000009CBF098508F240C09CBF...           11801
# 648  010300000001000000050000009CBF098508F240C09CBF...           11801
# 649  010300000001000000050000009CBF098508F240C09CBF...           11801
# 650  010300000001000000050000007288B83995F740C07288...           11802
# 651  010300000001000000050000007288B83995F740C07288...           11802
# 652  010300000001000000050000007288B83995F740C07288...           11802
# 653  010300000001000000050000007288B83995F740C07288...           11802
# 654  010300000001000000050000009CBF098508F240C09CBF...           11801
# 655  010300000001000000050000009CBF098508F240C09CBF...           11801
# 656  010300000001000000050000009CBF098508F240C09CBF...           11801
# 657  010300000001000000050000009CBF098508F240C09CBF...           11801
# 658  010300000001000000050000007288B83995F740C07288...           11802
# 659  010300000001000000050000007288B83995F740C07288...           11802
# 660  010300000001000000050000007288B83995F740C07288...           11802
# 661  010300000001000000050000007288B83995F740C07288...           11802
# 662  010300000001000000050000009CBF098508F240C09CBF...           11801
# 663  010300000001000000050000009CBF098508F240C09CBF...           11801
# 664  010300000001000000050000009CBF098508F240C09CBF...           11801
# 665  010300000001000000050000009CBF098508F240C09CBF...           11801
# 666  010300000001000000050000007288B83995F740C07288...           11802
# 667  010300000001000000050000007288B83995F740C07288...           11802
# 668  010300000001000000050000007288B83995F740C07288...           11802
# 669  010300000001000000050000007288B83995F740C07288...           11802
# 670  010300000001000000050000009CBF098508F240C09CBF...           11801
# 671  010300000001000000050000009CBF098508F240C09CBF...           11801
#
#                         ...                      arts  pod_id  \
# 0                       ...                        36     349
# 1                       ...                        36     349
# 2                       ...                        32     294
# 3                       ...                        32     294
# 4                       ...                        32     294
# 5                       ...                        32     294
# 6                       ...                        36     378
# 7                       ...                        36     378
# 8                       ...                        32     196
# 9                       ...                        32     196
# 10                      ...                        32     196
# 11                      ...                        32     196
# 12                      ...                        36     372
# 13                      ...                        36     372
# 14                      ...                        82      88
# 15                      ...                        36     228
# 16                      ...                        36     228
# 17                      ...                        36     155
# 18                      ...                        36     155
# 19                      ...                        36     350
# 20                      ...                        36     350
# 21                      ...                        36     279
# 22                      ...                        36     279
# 23                      ...                        36     149
# 24                      ...                        36     149
# 25                      ...                        32      73
# 26                      ...                        32      73
# 27                      ...                        32      73
# 28                      ...                        32      73
# 29                      ...                        32     484
# ..                      ...                       ...     ...
# 642                     ...                        32      24
# 643                     ...                        32      24
# 644                     ...                        32      24
# 645                     ...                        32      24
# 646                     ...                        36     135
# 647                     ...                        36     135
# 648                     ...                        36     402
# 649                     ...                        36     402
# 650                     ...                        32     381
# 651                     ...                        32     381
# 652                     ...                        32     381
# 653                     ...                        32     381
# 654                     ...                        36     415
# 655                     ...                        36     415
# 656                     ...                        36     369
# 657                     ...                        36     369
# 658                     ...                        32     497
# 659                     ...                        32     497
# 660                     ...                        32     497
# 661                     ...                        32     497
# 662                     ...                        36     252
# 663                     ...                        36     252
# 664                     ...                        36     227
# 665                     ...                        36     227
# 666                     ...                        32     198
# 667                     ...                        32     198
# 668                     ...                        32     198
# 669                     ...                        32     198
# 670                     ...                        36     473
# 671                     ...                        36     473
#
#                                                   name  n_cars  \
# 0                          Kings Cross- Kellett Street       1
# 1                          Kings Cross- Kellett Street       1
# 2                        Newtown South - Darley Street       1
# 3                        Newtown South - Darley Street       1
# 4                        Newtown South - Darley Street       1
# 5                        Newtown South - Darley Street       1
# 6                             Paddington - Greens Road       1
# 7                             Paddington - Greens Road       1
# 8                             Zetland - Gadigal Avenue       2
# 9                             Zetland - Gadigal Avenue       2
# 10                            Zetland - Gadigal Avenue       2
# 11                            Zetland - Gadigal Avenue       2
# 12                         Elizabeth Bay - Ithaca Road       1
# 13                         Elizabeth Bay - Ithaca Road       1
# 14                        St Leonards - Herbert Street       2
# 15                              Glebe - Arundel Street       1
# 16                              Glebe - Arundel Street       1
# 17                             Haymarket - Quay Street       1
# 18                             Haymarket - Quay Street       1
# 19                       Potts Point - Tusculum Street       1
# 20                       Potts Point - Tusculum Street       1
# 21        Potts Point - Ward Avenue near Kellett Place       1
# 22        Potts Point - Ward Avenue near Kellett Place       1
# 23                                 Glebe - Cook Street       1
# 24                                 Glebe - Cook Street       1
# 25                   Randwick - Silver Street Car Park       2
# 26                   Randwick - Silver Street Car Park       2
# 27                   Randwick - Silver Street Car Park       2
# 28                   Randwick - Silver Street Car Park       2
# 29                          Clovelly - Frenchmans Road       1
# ..                                                 ...     ...
# 642            Marrickville - Frampton Avenue Car Park       3
# 643            Marrickville - Frampton Avenue Car Park       3
# 644            Marrickville - Frampton Avenue Car Park       3
# 645            Marrickville - Frampton Avenue Car Park       3
# 646                                 St Marys Cathedral       1
# 647                                 St Marys Cathedral       1
# 648                        Sydney CBD - 1 Martin Place       2
# 649                        Sydney CBD - 1 Martin Place       2
# 650                       Kingsford - Harbourne Street       1
# 651                       Kingsford - Harbourne Street       1
# 652                       Kingsford - Harbourne Street       1
# 653                       Kingsford - Harbourne Street       1
# 654  Darlinghurst - Liverpool Street near Bourke St...       1
# 655  Darlinghurst - Liverpool Street near Bourke St...       1
# 656                            Pyrmont - Bowman Street       1
# 657                            Pyrmont - Bowman Street       1
# 658                           Randwick - Howard Street       1
# 659                           Randwick - Howard Street       1
# 660                           Randwick - Howard Street       1
# 661                           Randwick - Howard Street       1
# 662                        Camperdown - Missenden Road       1
# 663                        Camperdown - Missenden Road       1
# 664                         Bondi North - Ramsgate Ave       1
# 665                         Bondi North - Ramsgate Ave       1
# 666                    Erskineville - Macdonald Street       1
# 667                    Erskineville - Macdonald Street       1
# 668                    Erskineville - Macdonald Street       1
# 669                    Erskineville - Macdonald Street       1
# 670  Elizabeth Bay - Elizabeth Bay Road corner Ward...       1
# 671  Elizabeth Bay - Elizabeth Bay Road corner Ward...       1
#
#                                            description  \
# 0    in a dedicated parking bay - generously provid...
# 1    in a dedicated parking bay - generously provid...
# 2    on Darley Street, near the corner of King Stre...
# 3    on Darley Street, near the corner of King Stre...
# 4    on Darley Street, near the corner of King Stre...
# 5    on Darley Street, near the corner of King Stre...
# 6    in a dedicated bay on Greens Road just off Oxf...
# 7    in a dedicated bay on Greens Road just off Oxf...
# 8    a dedicated bay outside the shops on Gadigal A...
# 9    a dedicated bay outside the shops on Gadigal A...
# 10   a dedicated bay outside the shops on Gadigal A...
# 11   a dedicated bay outside the shops on Gadigal A...
# 12   in a dedicated bay on Ithaca Road just before ...
# 13   in a dedicated bay on Ithaca Road just before ...
# 14   This pod located on Herbert St, about 100m up ...
# 15   in a didicated parking bay outside 63 Arundel ...
# 16   in a didicated parking bay outside 63 Arundel ...
# 17   on Quay Street, just north of Bijou Lane. This...
# 18   on Quay Street, just north of Bijou Lane. This...
# 19   east side of Tusculum Street on the corner of ...
# 20   east side of Tusculum Street on the corner of ...
# 21   in a dedicated bay on Ward Avenue, near the co...
# 22   in a dedicated bay on Ward Avenue, near the co...
# 23   on Cook street, near the corner of Glebe Point...
# 24   on Cook street, near the corner of Glebe Point...
# 25   in the Randwick council car park, on the south...
# 26   in the Randwick council car park, on the south...
# 27   in the Randwick council car park, on the south...
# 28   in the Randwick council car park, on the south...
# 29   in an unrestricted location on Frenchmans Road...
# ..                                                 ...
# 642  in the council car park on Frampton avenue, cl...
# 643  in the council car park on Frampton avenue, cl...
# 644  in the council car park on Frampton avenue, cl...
# 645  in the council car park on Frampton avenue, cl...
# 646                                 St Marys Cathedral
# 647                                 St Marys Cathedral
# 648  at No. 1 Martin Place. The  entrance and exit ...
# 649  at No. 1 Martin Place. The  entrance and exit ...
# 650  in the first parking space on Harbourne Street...
# 651  in the first parking space on Harbourne Street...
# 652  in the first parking space on Harbourne Street...
# 653  in the first parking space on Harbourne Street...
# 654  on Liverpool Street close to Bourke Street, go...
# 655  on Liverpool Street close to Bourke Street, go...
# 656  in a dedicated bay on Bowman Street, near Moun...
# 657  in a dedicated bay on Bowman Street, near Moun...
# 658  on Howard Street on the corner of Perouse Road...
# 659  on Howard Street on the corner of Perouse Road...
# 660  on Howard Street on the corner of Perouse Road...
# 661  on Howard Street on the corner of Perouse Road...
# 662  in a dedicated bay on Missenden Road, on the c...
# 663  in a dedicated bay on Missenden Road, on the c...
# 664  in a dedicated bay on Ramsgate Avenue,  just e...
# 665  in a dedicated bay on Ramsgate Avenue,  just e...
# 666  in a dedicated bay on Macdonald Street, near t...
# 667  in a dedicated bay on Macdonald Street, near t...
# 668  in a dedicated bay on Macdonald Street, near t...
# 669  in a dedicated bay on Macdonald Street, near t...
# 670  in a dedicated bay on Elizabeth Bay Road on th...
# 671  in a dedicated bay on Elizabeth Bay Road on th...
#
#                                        location  station_id  \
# 0    010100000087F9F202ECEF40C0B003E78C28E76240         127
# 1    010100000087F9F202ECEF40C0B003E78C28E76240          34
# 2    010100000095607138F3F340C069FCC22BC9E56240         150
# 3    010100000095607138F3F340C069FCC22BC9E56240          96
# 4    010100000095607138F3F340C069FCC22BC9E56240          60
# 5    010100000095607138F3F340C069FCC22BC9E56240          44
# 6    0101000000F8FA5A971AF140C02DEBFEB110E76240         127
# 7    0101000000F8FA5A971AF140C02DEBFEB110E76240          34
# 8    010100000009FB761211F440C0857B65DEAAE66240         150
# 9    010100000009FB761211F440C0857B65DEAAE66240          96
# 10   010100000009FB761211F440C0857B65DEAAE66240          60
# 11   010100000009FB761211F440C0857B65DEAAE66240          44
# 12   01010000007AE40F069EEF40C07D93A64151E76240         127
# 13   01010000007AE40F069EEF40C07D93A64151E76240          34
# 14   01010000005305A3923AE940C02E90A0F831E66240           2
# 15   01010000001C3F541A31F140C09A5C8C81F5E56240         127
# 16   01010000001C3F541A31F140C09A5C8C81F5E56240          34
# 17   0101000000E0F60489EDF040C0459DB98784E66240         127
# 18   0101000000E0F60489EDF040C0459DB98784E66240          34
# 19   0101000000AB96749483EF40C0919C4CDC2AE76240         127
# 20   0101000000AB96749483EF40C0919C4CDC2AE76240          34
# 21   010100000098309A95EDEF40C0C366800B32E76240         127
# 22   010100000098309A95EDEF40C0C366800B32E76240          34
# 23   0101000000FAD4B14AE9EF40C0DE938785DAE56240         127
# 24   0101000000FAD4B14AE9EF40C0DE938785DAE56240          34
# 25   01010000003EE8D9ACFAF440C08B6CE7FBA9E76240         150
# 26   01010000003EE8D9ACFAF440C08B6CE7FBA9E76240          96
# 27   01010000003EE8D9ACFAF440C08B6CE7FBA9E76240          60
# 28   01010000003EE8D9ACFAF440C08B6CE7FBA9E76240          44
# 29   0101000000A662635E47F440C020B24813EFE76240         150
# ..                                          ...         ...
# 642  01010000009B1BD31396F440C0CF4D9B711AE56240         150
# 643  01010000009B1BD31396F440C0CF4D9B711AE56240          96
# 644  01010000009B1BD31396F440C0CF4D9B711AE56240          60
# 645  01010000009B1BD31396F440C0CF4D9B711AE56240          44
# 646  01010000006B60AB048BEF40C0E6797077D6E66240         127
# 647  01010000006B60AB048BEF40C0E6797077D6E66240          34
# 648  010100000064CE33F625EF40C0319413EDAAE66240         127
# 649  010100000064CE33F625EF40C0319413EDAAE66240          34
# 650  010100000059F9653046F640C071FF91E950E76240         150
# 651  010100000059F9653046F640C071FF91E950E76240          96
# 652  010100000059F9653046F640C071FF91E950E76240          60
# 653  010100000059F9653046F640C071FF91E950E76240          44
# 654  01010000005512D90759F040C01D9430D3F6E66240         127
# 655  01010000005512D90759F040C01D9430D3F6E66240          34
# 656  010100000076C58CF0F6EE40C0A4C519C31CE66240         127
# 657  010100000076C58CF0F6EE40C0A4C519C31CE66240          34
# 658  0101000000AE81AD122CF640C0AD31E884D0E76240         150
# 659  0101000000AE81AD122CF640C0AD31E884D0E76240          96
# 660  0101000000AE81AD122CF640C0AD31E884D0E76240          60
# 661  0101000000AE81AD122CF640C0AD31E884D0E76240          44
# 662  0101000000DC9F8B868CF140C0DE8D0585C1E56240         127
# 663  0101000000DC9F8B868CF140C0DE8D0585C1E56240          34
# 664  010100000080B8AB5791F140C0EE7C3F35DEE86240         127
# 665  010100000080B8AB5791F140C0EE7C3F35DEE86240          34
# 666  0101000000255CC823B8F340C0EFC517EDF1E56240         150
# 667  0101000000255CC823B8F340C0EFC517EDF1E56240          96
# 668  0101000000255CC823B8F340C0EFC517EDF1E56240          60
# 669  0101000000255CC823B8F340C0EFC517EDF1E56240          44
# 670  0101000000ADC3D155BAEF40C0151DC9E53FE76240         127
# 671  0101000000ADC3D155BAEF40C0151DC9E53FE76240          34
#
#                       station_name  \
# 0          Redfern_railway_station
# 1    Circular_Quay_railway_station
# 2         Sydenham_railway_station
# 3           Mascot_railway_station
# 4     Green_Square_railway_station
# 5     Dulwich_Hill_railway_station
# 6          Redfern_railway_station
# 7    Circular_Quay_railway_station
# 8         Sydenham_railway_station
# 9           Mascot_railway_station
# 10    Green_Square_railway_station
# 11    Dulwich_Hill_railway_station
# 12         Redfern_railway_station
# 13   Circular_Quay_railway_station
# 14        Artarmon_railway_station
# 15         Redfern_railway_station
# 16   Circular_Quay_railway_station
# 17         Redfern_railway_station
# 18   Circular_Quay_railway_station
# 19         Redfern_railway_station
# 20   Circular_Quay_railway_station
# 21         Redfern_railway_station
# 22   Circular_Quay_railway_station
# 23         Redfern_railway_station
# 24   Circular_Quay_railway_station
# 25        Sydenham_railway_station
# 26          Mascot_railway_station
# 27    Green_Square_railway_station
# 28    Dulwich_Hill_railway_station
# 29        Sydenham_railway_station
# ..                             ...
# 642       Sydenham_railway_station
# 643         Mascot_railway_station
# 644   Green_Square_railway_station
# 645   Dulwich_Hill_railway_station
# 646        Redfern_railway_station
# 647  Circular_Quay_railway_station
# 648        Redfern_railway_station
# 649  Circular_Quay_railway_station
# 650       Sydenham_railway_station
# 651         Mascot_railway_station
# 652   Green_Square_railway_station
# 653   Dulwich_Hill_railway_station
# 654        Redfern_railway_station
# 655  Circular_Quay_railway_station
# 656        Redfern_railway_station
# 657  Circular_Quay_railway_station
# 658       Sydenham_railway_station
# 659         Mascot_railway_station
# 660   Green_Square_railway_station
# 661   Dulwich_Hill_railway_station
# 662        Redfern_railway_station
# 663  Circular_Quay_railway_station
# 664        Redfern_railway_station
# 665  Circular_Quay_railway_station
# 666       Sydenham_railway_station
# 667         Mascot_railway_station
# 668   Green_Square_railway_station
# 669   Dulwich_Hill_railway_station
# 670        Redfern_railway_station
# 671  Circular_Quay_railway_station
#
#                                     sw_location  \
# 0    0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 1    0101000000859883DC66EE40C0859883DC66EE40C0
# 2    01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 3    010100000084E969B256F640C084E969B256F640C0
# 4    0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 5    01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 6    0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 7    0101000000859883DC66EE40C0859883DC66EE40C0
# 8    01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 9    010100000084E969B256F640C084E969B256F640C0
# 10   0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 11   01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 12   0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 13   0101000000859883DC66EE40C0859883DC66EE40C0
# 14   0101000000815C1AFBB3E740C0815C1AFBB3E740C0
# 15   0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 16   0101000000859883DC66EE40C0859883DC66EE40C0
# 17   0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 18   0101000000859883DC66EE40C0859883DC66EE40C0
# 19   0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 20   0101000000859883DC66EE40C0859883DC66EE40C0
# 21   0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 22   0101000000859883DC66EE40C0859883DC66EE40C0
# 23   0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 24   0101000000859883DC66EE40C0859883DC66EE40C0
# 25   01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 26   010100000084E969B256F640C084E969B256F640C0
# 27   0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 28   01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 29   01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# ..                                          ...
# 642  01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 643  010100000084E969B256F640C084E969B256F640C0
# 644  0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 645  01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 646  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 647  0101000000859883DC66EE40C0859883DC66EE40C0
# 648  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 649  0101000000859883DC66EE40C0859883DC66EE40C0
# 650  01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 651  010100000084E969B256F640C084E969B256F640C0
# 652  0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 653  01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 654  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 655  0101000000859883DC66EE40C0859883DC66EE40C0
# 656  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 657  0101000000859883DC66EE40C0859883DC66EE40C0
# 658  01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 659  010100000084E969B256F640C084E969B256F640C0
# 660  0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 661  01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 662  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 663  0101000000859883DC66EE40C0859883DC66EE40C0
# 664  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 665  0101000000859883DC66EE40C0859883DC66EE40C0
# 666  01010000003FADFDF8A6F540C03FADFDF8A6F540C0
# 667  010100000084E969B256F640C084E969B256F640C0
# 668  0101000000B9BEA2F22BF440C0B9BEA2F22BF440C0
# 669  01010000000D0F4FA1CAF440C00D0F4FA1CAF440C0
# 670  0101000000CE76CE9C60F240C0CE76CE9C60F240C0
# 671  0101000000859883DC66EE40C0859883DC66EE40C0
#
#                                     ne_location
# 0    0101000000A93AAC3408F240C0103BE1F468E66240
# 1    0101000000605C61740EEE40C0A646D12DC9E66240
# 2    0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 3    010100000061AD474AFEF540C0D31B32A308E66240
# 4    01010000009482808AD3F340C0D2029D7385E66240
# 5    0101000000E8D22C3972F440C0D02EC8C08FE46240
# 6    0101000000A93AAC3408F240C0103BE1F468E66240
# 7    0101000000605C61740EEE40C0A646D12DC9E66240
# 8    0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 9    010100000061AD474AFEF540C0D31B32A308E66240
# 10   01010000009482808AD3F340C0D2029D7385E66240
# 11   0101000000E8D22C3972F440C0D02EC8C08FE46240
# 12   0101000000A93AAC3408F240C0103BE1F468E66240
# 13   0101000000605C61740EEE40C0A646D12DC9E66240
# 14   01010000005C20F8925BE740C07D3E5895F7E56240
# 15   0101000000A93AAC3408F240C0103BE1F468E66240
# 16   0101000000605C61740EEE40C0A646D12DC9E66240
# 17   0101000000A93AAC3408F240C0103BE1F468E66240
# 18   0101000000605C61740EEE40C0A646D12DC9E66240
# 19   0101000000A93AAC3408F240C0103BE1F468E66240
# 20   0101000000605C61740EEE40C0A646D12DC9E66240
# 21   0101000000A93AAC3408F240C0103BE1F468E66240
# 22   0101000000605C61740EEE40C0A646D12DC9E66240
# 23   0101000000A93AAC3408F240C0103BE1F468E66240
# 24   0101000000605C61740EEE40C0A646D12DC9E66240
# 25   0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 26   010100000061AD474AFEF540C0D31B32A308E66240
# 27   01010000009482808AD3F340C0D2029D7385E66240
# 28   0101000000E8D22C3972F440C0D02EC8C08FE46240
# 29   0101000000CDCEFD309DF540C0FCAE63B76AE56240
# ..                                          ...
# 642  0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 643  010100000061AD474AFEF540C0D31B32A308E66240
# 644  01010000009482808AD3F340C0D2029D7385E66240
# 645  0101000000E8D22C3972F440C0D02EC8C08FE46240
# 646  0101000000A93AAC3408F240C0103BE1F468E66240
# 647  0101000000605C61740EEE40C0A646D12DC9E66240
# 648  0101000000A93AAC3408F240C0103BE1F468E66240
# 649  0101000000605C61740EEE40C0A646D12DC9E66240
# 650  0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 651  010100000061AD474AFEF540C0D31B32A308E66240
# 652  01010000009482808AD3F340C0D2029D7385E66240
# 653  0101000000E8D22C3972F440C0D02EC8C08FE46240
# 654  0101000000A93AAC3408F240C0103BE1F468E66240
# 655  0101000000605C61740EEE40C0A646D12DC9E66240
# 656  0101000000A93AAC3408F240C0103BE1F468E66240
# 657  0101000000605C61740EEE40C0A646D12DC9E66240
# 658  0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 659  010100000061AD474AFEF540C0D31B32A308E66240
# 660  01010000009482808AD3F340C0D2029D7385E66240
# 661  0101000000E8D22C3972F440C0D02EC8C08FE46240
# 662  0101000000A93AAC3408F240C0103BE1F468E66240
# 663  0101000000605C61740EEE40C0A646D12DC9E66240
# 664  0101000000A93AAC3408F240C0103BE1F468E66240
# 665  0101000000605C61740EEE40C0A646D12DC9E66240
# 666  0101000000CDCEFD309DF540C0FCAE63B76AE56240
# 667  010100000061AD474AFEF540C0D31B32A308E66240
# 668  01010000009482808AD3F340C0D2029D7385E66240
# 669  0101000000E8D22C3972F440C0D02EC8C08FE46240
# 670  0101000000A93AAC3408F240C0103BE1F468E66240
# 671  0101000000605C61740EEE40C0A646D12DC9E66240
#
# [672 rows x 26 columns]

# %%
# Only join the Neighbourhoods, BusinessStats, StatisticalArea and CensusStats table
join_all = """
            CREATE VIEW view_tables
            AS
            SELECT * 
            FROM Neighbourhoods N
            natural join BusinessStats BS
            natural join StatisticalArea SA
            natural join CensusStats CS
            ;
        """
pgexec(conn, join_all, None, "join successfully")
# Out:
# success: join successfully
# True

# %%
#Show the created view
import pandas
data = pandas.read_sql_query("SELECT * FROM view_tables", conn)
data
# Out:
#        area_id                                area_name  n_businesses  \
# 0    102011028                 Avoca Beach - Copacabana           738
# 1    102011029              Box Head - MacMasters Beach           907
# 2    102011030                          Calga - Kulnura          1102
# 3    102011031                      Erina - Green Point          1666
# 4    102011032                    Gosford - Springfield          2126
# 5    102011033                                  Kariong           352
# 6    102011034              Kincumber - Picketts Valley           479
# 7    102011035                                   Narara           292
# 8    102011036                   Niagara Park - Lisarow           477
# 9    102011037                  Point Clare - Koolewong           312
# 10   102011038                     Saratoga - Davistown           486
# 11   102011039                   Terrigal - North Avoca          1351
# 12   102011040             Umina - Booker Bay - Patonga          1217
# 13   102011041              Wamberal - Forresters Beach           924
# 14   102011042                      Woy Woy - Blackwall           691
# 15   102011043                                  Wyoming           486
# 16   102021044              Bateau Bay - Killarney Vale          1035
# 17   102021045                    Blue Haven - San Remo           290
# 18   102021046       Budgewoi - Buff Point - Halekulani           350
# 19   102021047               Chittaway Bay - Tumbi Umbi           994
# 20   102021048            Gorokan - Kanwal - Charmhaven           816
# 21   102021049                    Jilliby - Yarramalong           390
# 22   102021050           Lake Munmorah - Mannering Park           424
# 23   102021051                  Ourimbah - Fountaindale           439
# 24   102021052             Summerland Point - Gwandalan           287
# 25   102021053                             The Entrance          1000
# 26   102021054                     Toukley - Norah Head           588
# 27   102021055                    Tuggerah - Kangy Angy           973
# 28   102021056                     Warnervale - Wadalba           768
# 29   102021057                                    Wyong           645
# ..         ...                                      ...           ...
# 282  127021515                                Fairfield          1364
# 283  127021516                         Fairfield - West           959
# 284  127021517            Greenfield Park - Prairiewood           493
# 285  127021518               Horsley Park - Kemps Creek           963
# 286  127021519              Smithfield - Wetherill Park          1393
# 287  127021520                  St Johns Park - Wakeley           624
# 288  127021521                Wetherill Park Industrial          1693
# 289  127031522                                   Casula          1092
# 290  127031523              Chipping Norton - Moorebank          2431
# 291  127031524                Holsworthy - Wattle Grove          1148
# 292  127031598                                Liverpool          2589
# 293  127031599                      Lurnea - Cartwright           462
# 294  127031600                Prestons - Edmondson Park          1668
# 295  127031601                             Warwick Farm           330
# 296  128011529                      Gymea - Grays Point          1421
# 297  128011530                      Miranda - Yowie Bay          2217
# 298  128011531                   Sylvania - Taren Point          2301
# 299  128011602                                Caringbah          2052
# 300  128011603                          Caringbah South          1157
# 301  128011604            Cronulla - Kurnell - Bundeena          2485
# 302  128011605  Lilli Pilli - Port Hacking - Dolans Bay           442
# 303  128011606                    Woolaware - Burraneer           924
# 304  128021533                    Heathcote - Waterfall           377
# 305  128021534                 Illawong - Alfords Point          1138
# 306  128021535         Menai - Lucas Heights - Woronora          1595
# 307  128021536              Oyster Bay - Como - Jannali          1591
# 308  128021537                      Royal National Park             3
# 309  128021538                    Sutherland - Kirrawee          2086
# 310  128021608                     Loftus - Yarrawarrah           417
# 311  128021609                         Woronora Heights           259
#
#      land_area  population  n_dwellings  num_pods  num_stations  \
# 0        643.8        7590         2325         0             0
# 1       3208.6       10986         3847         0             0
# 2      76795.1        4841         1575         0             0
# 3       3379.3       14237         4450         0             0
# 4       1691.2       19385         6373         0             0
# 5        830.6        6540         1824         0             0
# 6       1208.9        7428         1946         0             0
# 7        770.2        6853         2006         0             0
# 8       1673.2        8173         2345         0             0
# 9        678.7        6281         2220         0             0
# 10       476.8        7177         2366         0             0
# 11      1010.7       14048         4457         0             0
# 12      2522.8       24251         7540         0             0
# 13      1372.2       10308         2947         0             0
# 14      1742.3       14327         4304         0             0
# 15       838.1       11659         3269         0             0
# 16      1086.0       22465         6941         0             0
# 17      2098.0       11366         3624         0             0
# 18       935.3        9639         3648         0             0
# 19      2449.9       15697         4947         0             0
# 20      1124.9       22567         7562         0             0
# 21     34676.6        3520          973         0             0
# 22      3549.5       11093         4252         0             0
# 23     11411.7        4996         1317         0             0
# 24       917.9        5904         2143         0             0
# 25      1385.8       15416         4428         0             0
# 26      1052.2       10092         3208         0             0
# 27      2784.6        5480         1420         0             0
# 28      4289.0       16365         4387         0             0
# 29      1503.3        9114         2805         0             0
# ..         ...         ...          ...       ...           ...
# 282      423.0       18664         4786         0             0
# 283      469.2       20214         4309         0             0
# 284      363.7        8716         2066         0             1
# 285     5627.7        4664         1150         0             0
# 286      661.2       18918         4902         0             1
# 287      361.1       11317         2721         0             1
# 288      855.7          46            0         0             0
# 289      707.2       16488         3430         0             2
# 290     1449.0       19823         5132         0             1
# 291     7370.0       21699         5392         0             1
# 292      631.9       29585         7443         0             0
# 293      346.7       12310         2897         0             1
# 294     1413.2       19219         4408         0             4
# 295      465.0        6470         1981         0             0
# 296      579.8       18057         5103         0             0
# 297      599.7       18975         5471         0             0
# 298      607.3       16733         4449         0             1
# 299      399.6       12388         3441         0             0
# 300      407.0       12572         3236         0             1
# 301     2508.7       24795         9038         0             1
# 302      127.1        3265          912         0             0
# 303      332.8        8260         2143         0             0
# 304     2761.6        6674         1964         0             0
# 305      729.8       10756         3032         0             1
# 306     3340.5       21656         5523         0             0
# 307      890.5       22084         5931         0             1
# 308    13933.4          28            4         0             0
# 309      775.5       21760         6924         0             1
# 310      384.4        7426         2177         0             1
# 311      313.7        3681         1050         0             1
#
#                                               boundary  retail_trade  \
# 0    010300000001000000050000004673092C25BF40C04673...            35
# 1    010300000001000000050000009E5F94A0BFC140C09E5F...            42
# 2    0103000000010000000500000029C709B88CB940C029C7...            42
# 3    0103000000010000000500000059D29B9B80B940C059D2...           143
# 4    01030000000100000005000000E7806E79F6B740C0E780...           159
# 5    010300000001000000050000002ADD02AED0BE40C02ADD...            18
# 6    010300000001000000050000007DFCEFD297BB40C07DFC...            31
# 7    0103000000010000000500000001C5234CACB440C001C5...            14
# 8    0103000000010000000500000066C7FC9243B240C066C7...            22
# 9    010300000001000000050000009D499BAA7BBD40C09D49...            10
# 10   010300000001000000050000006641727CFEBE40C06641...            32
# 11   010300000001000000050000006479573D60BB40C06479...            66
# 12   01030000000100000005000000E1421EC18DC240C0E142...            73
# 13   01030000000100000005000000CD84155DCDB540C0CD84...            36
# 14   01030000000100000005000000A553B2F73DC140C0A553...            53
# 15   01030000000100000005000000D5E940D6537F44408038...            23
# 16   010300000001000000050000000E27D5E363B040C00E27...            50
# 17   010300000001000000050000004864C4AAE69B40C04864...            17
# 18   010300000001000000050000006AA8AC01A59E40C06AA8...            16
# 19   0103000000010000000500000059A0826852AA40C059A0...            55
# 20   010300000001000000050000003D5C1723B7A140C03D5C...            65
# 21   010300000001000000050000000CC803368C9E40C00CC8...            16
# 22   01030000000100000005000000D0622992AF9A40C0D062...            26
# 23   0103000000010000000500000079FFC46DD9AE40C079FF...            31
# 24   010300000001000000050000003D5D82F8659340C03D5D...            14
# 25   01030000000100000005000000F4AA2924F4AC40C0F4AA...            84
# 26   01030000000100000005000000E0F41C8325A140C0E0F4...            47
# 27   010300000001000000050000001146A28625AB40C01146...            68
# 28   01030000000100000005000000267F411C35A440C0267F...            44
# 29   01030000000100000005000000D30A1D8535A640C0D30A...            34
# ..                                                 ...           ...
# 282  01030000000100000005000000CC907417728E44408BD5...           142
# 283  010300000001000000050000002F7B355F5FAC4340BF47...            63
# 284  01030000000100000005000000A5017278F7F040C0A501...            28
# 285  01030000000100000005000000DF56D526A9EE40C0DF56...            49
# 286  010300000001000000050000007AE981EA7AEE40C07AE9...            89
# 287  01030000000100000005000000CFBF5DF6EBF040C0CFBF...            40
# 288  01030000000100000005000000916E285DC0EB40C0916E...            97
# 289  010300000001000000050000000FD3BEB9BFFB40C00FD3...            85
# 290  010300000001000000050000001E311FB52EF740C01E31...           170
# 291  010300000001000000050000001FD7868A71FB40C01FD7...            57
# 292  010300000001000000050000009E89FA6E04A94A40555A...           206
# 293  0103000000010000000500000066D8CD31C5F640C066D8...            36
# 294  010300000001000000050000007FF21C3636FD40C07FF2...           106
# 295  01030000000100000005000000F4DF83D72EF640C0F4DF...            29
# 296  01030000000100000005000000326E0FE7860841C0326E...            60
# 297  010300000001000000050000002D944C4EED0741C02D94...           154
# 298  010300000001000000050000005FE57569680341C05FE5...           145
# 299  01030000000100000005000000F15FC54E1D0641C0F15F...           136
# 300  01030000000100000005000000D1132A93750841C0D113...            56
# 301  0103000000010000000500000056702EB4290C41C05670...           119
# 302  01030000000100000005000000B3F391EFAD0841C0B3F3...             9
# 303  01030000000100000005000000E118B8F2480941C0E118...            45
# 304  01030000000100000005000000FA92324EE81241C0FA92...            23
# 305  01030000000100000005000000FB6FCA81C3FF40C0FB6F...            51
# 306  010300000001000000050000001409A69A590441C01409...            77
# 307  0103000000010000000500000049699148360141C04969...            90
# 308  0103000000010000000500000016341B56C80941C01634...             0
# 309  01030000000100000005000000D000DE02090641C0D000...           107
# 310  01030000000100000005000000C1A90F24EF0741C0C1A9...            17
# 311  01030000000100000005000000E43D18C27B0541C0E43D...            10
#
#      accomodationfoodservices  healthycare_socialassistance  education  arts  \
# 0                          33                            62          9    20
# 1                          21                            43         11    29
# 2                          17                            11         18    23
# 3                          68                           164         22    15
# 4                          95                           230         36    27
# 5                          14                            18          5     8
# 6                          21                            40         14    11
# 7                           5                            16          8     8
# 8                          17                            27         10     3
# 9                           9                            20          5     7
# 10                         14                            20          4    12
# 11                         70                           167         25    21
# 12                         76                            57         22    23
# 13                         31                            66         12    16
# 14                         51                            41         10    10
# 15                         30                            43         12    11
# 16                         32                            59         15    15
# 17                          9                             9          0     4
# 18                         17                            15          4     3
# 19                         24                            51         17     8
# 20                         34                            54         16    12
# 21                          6                            15          4     4
# 22                         20                            16          6     3
# 23                         10                            34          6    11
# 24                         11                            10          5     0
# 25                         79                            54         11    18
# 26                         44                            40         11     8
# 27                         41                            38         16     8
# 28                         28                            49         22     9
# 29                         58                            28         12    12
# ..                        ...                           ...        ...   ...
# 282                        64                           111         12     5
# 283                        40                            73         14     3
# 284                        27                            21          5     0
# 285                        21                            17          8     5
# 286                        44                            54         16    12
# 287                        26                            24          3     3
# 288                        20                             6          8    12
# 289                        31                            65         10    16
# 290                        70                            75         19    16
# 291                        45                            69         22     9
# 292                       107                           266         29     9
# 293                         5                            17         13     3
# 294                        48                            68         21    14
# 295                         3                             9          0    22
# 296                        41                            73         24    26
# 297                        78                           209         26    25
# 298                        96                            90         17    30
# 299                        82                            91         22    19
# 300                        23                            67         19    11
# 301                       130                           109         42    42
# 302                        14                            22          5     4
# 303                        23                            56         17    15
# 304                         8                            12         13     3
# 305                        26                            76         12    10
# 306                        46                            92         39    21
# 307                        49                            84         24    24
# 308                         3                             0          0     0
# 309                        79                           134         36    27
# 310                         6                            17          7     7
# 311                         5                            10          0     7
#
#      parent_area_id  income  avg_rent
# 0             10201   46996      1906
# 1             10201   42621      1682
# 2             10201   42105      1182
# 3             10201   43481      1595
# 4             10201   45972      1382
# 5             10201   47896      1649
# 6             10201   41642      1397
# 7             10201   46660      1512
# 8             10201   45762      1495
# 9             10201   45966      1572
# 10            10201   43171      1667
# 11            10201   46422      2022
# 12            10201   40252      1517
# 13            10201   47295      1902
# 14            10201   42481      1387
# 15            10201   43438      1466
# 16            10202   42469      1423
# 17            10202   42641      1526
# 18            10202   41702      1347
# 19            10202   45015      1593
# 20            10202   41051      1330
# 21            10202   44122      1364
# 22            10202   41152      1363
# 23            10202   48214      1469
# 24            10202   42683      1455
# 25            10202   44137      1404
# 26            10202   39615      1296
# 27            10202   44360      1699
# 28            10202   47983      1823
# 29            10202   41055      1276
# ..              ...     ...       ...
# 282           12702   39685      1478
# 283           12702   39701      1679
# 284           12702   45071      1640
# 285           12702   48258      1684
# 286           12702   43457      1535
# 287           12702   43397      1727
# 288           12702   46348         0
# 289           12703   47580      1703
# 290           12703   50891      1913
# 291           12703   57000      1805
# 292           12703   42303      1495
# 293           12703   40864      1217
# 294           12703   51121      2044
# 295           12703   43106      1275
# 296           12801   52871      2113
# 297           12801   50319      1879
# 298           12801   47383      2059
# 299           12801   52754      1814
# 300           12801   52088      2606
# 301           12801   55083      2027
# 302           12801   57429      3086
# 303           12801   56652      2200
# 304           12802   49791      1785
# 305           12802   51600      2608
# 306           12802   54420      2183
# 307           12802   55391      1947
# 308           12802       0      1899
# 309           12802   53378      1809
# 310           12802   51243      2163
# 311           12802   54935      2300
#
# [312 rows x 17 columns]

# %% [markdown]
# ## walkability score calculation

# %%
import numpy
data['pop_density'] = data['population']/data['land_area']
data['dwelling_density'] = data['n_dwellings']/data['land_area']
data['transport_density'] = data['num_pods']/data['land_area']
data['trainStation_density'] = data['num_stations']/data['land_area']
data['service_balance'] = data['retail_trade']+data['accomodationfoodservices']+data['healthycare_socialassistance']+data['education']+data['arts']

data['pop_z_density'] = (data['pop_density']-data['pop_density'].mean())/data['pop_density'].std()
data['dwelling_z_density'] = (data['dwelling_density']-data['dwelling_density'].mean())/data['dwelling_density'].std()
data['transport_z_density'] = (data['transport_density']-data['transport_density'].mean())/data['transport_density'].std()
data['trainStation_z_density'] = (data['trainStation_density']-data['trainStation_density'].mean())/data['trainStation_density'].std()
data['service_z'] = (data['service_balance']-data['service_balance'].mean())/data['service_balance'].std()
data['walkability_score'] = data['pop_z_density']+data['dwelling_z_density']+data['transport_z_density']+data['service_z']+data['trainStation_z_density']

# %%
data.head()
# Out:
#      area_id                    area_name  n_businesses  land_area  \
# 0  102011028     Avoca Beach - Copacabana           738      643.8
# 1  102011029  Box Head - MacMasters Beach           907     3208.6
# 2  102011030              Calga - Kulnura          1102    76795.1
# 3  102011031          Erina - Green Point          1666     3379.3
# 4  102011032        Gosford - Springfield          2126     1691.2
#
#    population  n_dwellings  num_pods  num_stations  \
# 0        7590         2325         0             0
# 1       10986         3847         0             0
# 2        4841         1575         0             0
# 3       14237         4450         0             0
# 4       19385         6373         0             0
#
#                                             boundary  retail_trade  \
# 0  010300000001000000050000004673092C25BF40C04673...            35
# 1  010300000001000000050000009E5F94A0BFC140C09E5F...            42
# 2  0103000000010000000500000029C709B88CB940C029C7...            42
# 3  0103000000010000000500000059D29B9B80B940C059D2...           143
# 4  01030000000100000005000000E7806E79F6B740C0E780...           159
#
#          ...          dwelling_density  transport_density  \
# 0        ...                  3.611370                0.0
# 1        ...                  1.198965                0.0
# 2        ...                  0.020509                0.0
# 3        ...                  1.316841                0.0
# 4        ...                  3.768330                0.0
#
#    trainStation_density  service_balance  pop_z_density  dwelling_z_density  \
# 0                   0.0              159      -0.667128           -0.550210
# 1                   0.0              146      -0.986052           -0.854885
# 2                   0.0              111      -1.114182           -1.003718
# 3                   0.0              412      -0.955969           -0.839998
# 4                   0.0              547      -0.679598           -0.530387
#
#    transport_z_density  trainStation_z_density  service_z  walkability_score
# 0            -0.080708               -0.347179  -0.432262          -2.077487
# 1            -0.080708               -0.347179  -0.469316          -2.738140
# 2            -0.080708               -0.347179  -0.569078          -3.114865
# 3            -0.080708               -0.347179   0.288869          -1.934984
# 4            -0.080708               -0.347179   0.673663          -0.964209
#
# [5 rows x 28 columns]

# %%
data_final = data.loc[:,['area_id','area_name','pop_z_density','dwelling_z_density','service_z','transport_z_density','trainStation_z_density','walkability_score']]
data_final.head()
# Out:
#      area_id                    area_name  pop_z_density  dwelling_z_density  \
# 0  102011028     Avoca Beach - Copacabana      -0.667128           -0.550210
# 1  102011029  Box Head - MacMasters Beach      -0.986052           -0.854885
# 2  102011030              Calga - Kulnura      -1.114182           -1.003718
# 3  102011031          Erina - Green Point      -0.955969           -0.839998
# 4  102011032        Gosford - Springfield      -0.679598           -0.530387
#
#    service_z  transport_z_density  trainStation_z_density  walkability_score
# 0  -0.432262            -0.080708               -0.347179          -2.077487
# 1  -0.469316            -0.080708               -0.347179          -2.738140
# 2  -0.569078            -0.080708               -0.347179          -3.114865
# 3   0.288869            -0.080708               -0.347179          -1.934984
# 4   0.673663            -0.080708               -0.347179          -0.964209

# %%
import numpy
data["walkability_score"].describe()
# Out:
# count    3.120000e+02
# mean     5.010237e-16
# std      3.222577e+00
# min     -3.436244e+00
# 25%     -2.028230e+00
# 50%     -7.347594e-01
# 75%      1.032102e+00
# max      2.681239e+01
# Name: walkability_score, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.boxplot(data["walkability_score"])
plt.show()

# %%
plt.hist(data["walkability_score"],bins='auto')
plt.show()

# %% [markdown]
# ## Creating Index

# %%
#store the measure values alonbg with the area_id and area_name into the csv file

with open("index.csv","w") as output:
    fieldnames = ['area_id','area_name','pop_z_density','dwelling_z_density','service_z','transport_z_density','trainStation_z_density','walkability_score']
    writer = csv.DictWriter(output, fieldnames=fieldnames)
    writer.writeheader()
    #count = 0
    for count in range(0,len(data)):
        writer.writerow({'area_id':data['area_id'][count], 'area_name':data['area_name'][count], 'pop_z_density':data['pop_z_density'][count], 'dwelling_z_density': data['dwelling_z_density'][count], 'service_z': data['service_z'][count],'transport_z_density': data['transport_z_density'][count], 'trainStation_z_density': data['trainStation_z_density'][count], 'walkability_score': data['walkability_score'][count] })

# %%
data_Index = list(csv.DictReader(open('index.csv')))

# %%
# clean the data with string type in data_Index
# strip any leading or trailing spaces from the 'data_Index' values
clean(data_Index, 'area_name', str.strip, DEFAULT_VALUE)


# the following converts the 7 Pods columns to float or int values - or NaN
clean(data_Index, 'area_id', int, DEFAULT_VALUE)
clean(data_Index, 'pop_z_density', float, DEFAULT_VALUE)
clean(data_Index, 'dwelling_z_density', float, DEFAULT_VALUE)
clean(data_Index, 'service_z', float, DEFAULT_VALUE)
clean(data_Index, 'transport_z_density', float, DEFAULT_VALUE)
clean(data_Index, 'trainStation_z_density', float, DEFAULT_VALUE)
clean(data_Index, 'walkability_score', float, DEFAULT_VALUE)

# %%
# Create the Index_t table

pgexec(conn, "DROP TABLE IF EXISTS Index_t",None,"Reset Table Index_t")

Index_schema = """CREATE TABLE Index_t(
                            area_id INT NOT NULL, 
                            area_name VARCHAR(50) NOT NULL, 
                            pop_z_density FLOAT NOT NULL, 
                            dwelling_z_density INT NOT NULL, 
                            service_z FLOAT NOT NULL, 
                            transport_z_density FLOAT NOT NULL,
                            trainStation_z_density FLOAT NOT NULL,
                            walkability_score FLOAT NOT NULL,
                            PRIMARY KEY (area_id));
                        """

pgexec (conn, Index_schema, None, "Create Table Index_t")

# load the data into the Neighbourhoods table
insert_stmt = """INSERT INTO Index_t(area_id,area_name,pop_z_density,dwelling_z_density, service_z,transport_z_density, trainStation_z_density, walkability_score) 
                VALUES (%(area_id)s,%(area_name)s,%(pop_z_density)s,%(dwelling_z_density)s,%(service_z)s,%(transport_z_density)s, %(trainStation_z_density)s, %(walkability_score)s)"""
for row in data_Index:
    pgexec(conn,insert_stmt,row,"row inserted")
# Out:
# success: Reset Table Index_t
# success: Create Table Index_t
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %%
## create index based on Index_t table
create_index = """create index index_measure on index_t(area_name);
                  cluster index_t using index_measure"""
pgexec(conn, create_index, None, "ok")
# Out:
# success: ok
# True

# %%
#store the measure values alonbg with the area_id and area_name into the csv file

with open("index_spatial.csv","w") as output:
    fieldnames = ['area_id','n_businesses','area_name','land_area','population','n_dwellings','num_pods','num_stations','boundary', 'parent_area_id', 'income', 'avg_rent', 'retail_trade', 'accomodationfoodservices', 'healthycare_socialassistance', 'education', 'arts', 'pod_id', 'name', 'n_cars', 'description', 'location', 'station_id', 'station_name', 'sw_location', 'ne_location']
    writer = csv.DictWriter(output, fieldnames=fieldnames)
    writer.writeheader()
    for count in range(0,len(data_spatial)):
        writer.writerow({'area_id':data_spatial['area_id'][count], 'n_businesses':data_spatial['n_businesses'][count], 'area_name':data_spatial['area_name'][count], 'land_area': data_spatial['land_area'][count], 'population': data_spatial['population'][count],'n_dwellings': data_spatial['n_dwellings'][count], 'num_pods': data_spatial['num_pods'][count], 'num_stations': data_spatial['num_stations'][count], 'boundary': data_spatial['boundary'][count],'parent_area_id': data_spatial['parent_area_id'][count],'income': data_spatial['income'][count],'avg_rent': data_spatial['avg_rent'][count],'retail_trade': data_spatial['retail_trade'][count],'accomodationfoodservices': data_spatial['accomodationfoodservices'][count],'healthycare_socialassistance': data_spatial['healthycare_socialassistance'][count],'education': data_spatial['education'][count],'arts': data_spatial['arts'][count],'pod_id': data_spatial['pod_id'][count],'name': data_spatial['name'][count], 'n_cars': data_spatial['n_cars'][count], 'description': data_spatial['description'][count], 'location': data_spatial['location'][count], 'station_id': data_spatial['station_id'][count], 'station_name': data_spatial['station_name'][count], 'sw_location': data_spatial['sw_location'][count], 'ne_location': data_spatial['ne_location'][count], })

# %%
data_spatial_Index = list(csv.DictReader(open('index_spatial.csv')))

# %%
# Create the Index_spatial_t table

pgexec(conn, "DROP TABLE IF EXISTS Index_spatial_t",None,"Reset Table Index_spatial_t")

Index_spatial_schema = """CREATE TABLE Index_spatial_t(
                            area_id INT NOT NULL,
                            n_businesses INT,
                            area_name VARCHAR(50) NOT NULL, 
                            land_area FLOAT NOT NULL, 
                            population INT, 
                            n_dwellings INT, 
                            num_pods INT,
                            num_stations INT,
                            boundary GEOMETRY NOT NULL,
                            parent_area_id INT NOT NULL,
                            income INT,
                            avg_rent INT,
                            retail_trade INT,
                            accomodationfoodservices INT,
                            healthycare_socialassistance INT,
                            education INT,
                            arts INT,
                            pod_id INT,
                            name VARCHAR(500),
                            n_cars INT,
                            description VARCHAR(5000),
                            location GEOMETRY,
                            station_id INT,
                            station_name VARCHAR(500),
                            sw_location GEOMETRY,
                            ne_location GEOMETRY);
                        """

pgexec (conn, Index_spatial_schema, None, "Create Table Index_spatial_t")

# load the data into the Index_spatial_t table
insert_stmt = """INSERT INTO Index_spatial_t(area_id, n_businesses, area_name, land_area, population, n_dwellings, num_pods, num_stations, boundary, parent_area_id, income, avg_rent, retail_trade, accomodationfoodservices, healthycare_socialassistance, education, arts, pod_id, name, n_cars, description, location, station_id, station_name, sw_location, ne_location) 
                VALUES (%(area_id)s,%(n_businesses)s,%(area_name)s,%(land_area)s,%(population)s,%(n_dwellings)s, %(num_pods)s, %(num_stations)s, %(boundary)s, %(parent_area_id)s, %(income)s, %(avg_rent)s, %(retail_trade)s, %(accomodationfoodservices)s, %(healthycare_socialassistance)s, %(education)s, %(arts)s, %(pod_id)s, %(name)s, %(n_cars)s, %(description)s, %(location)s, %(station_id)s, %(station_name)s, %(sw_location)s, %(ne_location)s)"""
for row in data_spatial_Index:
    pgexec(conn,insert_stmt,row,"row inserted")
# Out:
# success: Reset Table Index_spatial_t
# success: Create Table Index_spatial_t
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted
# success: row inserted

# %%
## create spatial index based on Index_spatial_t table with boundary
create_spatial_index = """create index
                    on Index_spatial_t(boundary)"""
pgexec(conn, create_spatial_index, None, "ok")
# Out:
# success: ok
# True

# %% [markdown]
# ## Correlation

# %%
from scipy.stats.stats import pearsonr
print("correlation coefficient between houusehold median income and walkability score is " + str(pearsonr(data['income'], data_final["walkability_score"])[0]))
# Out:
# correlation coefficient between houusehold median income and walkability score is 0.263804647164

# %%
print("p-value of income-walikability score: "+str(pearsonr(data['income'], data_final["walkability_score"])[1]))
# Out:
# p-value of income-walikability score: 2.30139783477e-06

# %%
print("correlation coefficient between rent and walkability score is " + str(pearsonr(data['avg_rent'], data_final["walkability_score"])[0]))
# Out:
# correlation coefficient between rent and walkability score is 0.410324907201

# %%
print("p-value of rent-walikability score: "+str(pearsonr(data["avg_rent"], data_final["walkability_score"])[1]))
# Out:
# p-value of rent-walikability score: 4.22289845654e-14

# %%
import matplotlib.pyplot as plt
plt.scatter(data["income"],data_final["walkability_score"])
plt.ylabel('walkability score')
plt.xlabel('median household income')
plt.title('walkability score vs median household income')
plt.show()

# %%
plt.scatter(data["avg_rent"],data_final["walkability_score"])
plt.ylabel('walkability score')
plt.xlabel('average monthly rent')
plt.title('walkability score vs average monthly rent')
plt.show()

# %%
data_result = pandas.read_sql_query("SELECT * FROM Index_t order by walkability_score desc", conn)
data_result.head()
# Out:
#      area_id                       area_name  pop_z_density  \
# 0  118011347                       Woollahra       1.337514
# 1  117031337  Sydney - Haymarket - The Rocks       1.637255
# 2  117031333     Potts Point - Woolloomooloo       5.104751
# 3  117031334                Pyrmont - Ultimo       5.041288
# 4  117031329                    Darlinghurst       4.405826
#
#    dwelling_z_density  service_z  transport_z_density  trainstation_z_density  \
# 0                   1   0.060843            17.316662                7.171292
# 1                   2  13.725288            -0.080708               -0.347179
# 2                   7   1.035654            -0.080708               -0.347179
# 3                   5   1.158217            -0.080708               -0.347179
# 4                   5   1.183870            -0.080708               -0.347179
#
#    walkability_score
# 0          26.812386
# 1          16.565157
# 2          12.281314
# 3          11.202037
# 4           9.923514

# %%
data_result.loc[:,["area_id","area_name","walkability_score"]].head()
# Out:
#      area_id                    area_name  walkability_score
# 0  116021562               Acacia Gardens          -1.336118
# 1  119041375  Arncliffe - Bardwell Valley           1.001640
# 2  127011504    Ashcroft - Busby - Miller           0.956265
# 3  120031390                     Ashfield           3.265703
# 4  121021403        Asquith - Mount Colah          -2.389468

# %%
for r in range(0, len(data_Index)):
    data_Index[r].update(data_StatisticalArea[r])

# %%
import pprint
for row in data_Index:
    pprint.pprint(row)
# Out:
# OrderedDict([('area_id', 1),
#              ('area_name', 'New South Wales'),
#              ('pop_z_density', -0.667127523506),
#              ('dwelling_z_density', -0.550210389237),
#              ('service_z', -0.432262311939),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.07748710948),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 10),
#              ('area_name', 'Greater Sydney'),
#              ('pop_z_density', -0.986051541389),
#              ('dwelling_z_density', -0.85488511302),
#              ('service_z', -0.46931649947),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.73814003868),
#              ('parent_area_id', 1)])
# OrderedDict([('area_id', 11),
#              ('area_name', 'Rest of NSW'),
#              ('pop_z_density', -1.11418173746),
#              ('dwelling_z_density', -1.00371826838),
#              ('service_z', -0.569077773593),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.11486466423),
#              ('parent_area_id', 1)])
# OrderedDict([('area_id', 2),
#              ('area_name', 'Victoria'),
#              ('pop_z_density', -0.955968721125),
#              ('dwelling_z_density', -0.839998025172),
#              ('service_z', 0.28886918386),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.93498444723),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 20),
#              ('area_name', 'Greater Melbourne'),
#              ('pop_z_density', -0.679597875289),
#              ('dwelling_z_density', -0.530387097542),
#              ('service_z', 0.673662669761),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.964209187868),
#              ('parent_area_id', 2)])
# OrderedDict([('area_id', 21),
#              ('area_name', 'Rest of Victoria'),
#              ('pop_z_density', -0.816403701429),
#              ('dwelling_z_density', -0.72896421891),
#              ('service_z', -0.705893235246),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.67914804038),
#              ('parent_area_id', 2)])
# OrderedDict([('area_id', 3),
#              ('area_name', 'Queensland'),
#              ('pop_z_density', -0.882335144256),
#              ('dwelling_z_density', -0.803007842041),
#              ('service_z', -0.551975840886),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.66520571198),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 30),
#              ('area_name', 'Greater Brisbane'),
#              ('pop_z_density', -0.777370017272),
#              ('dwelling_z_density', -0.677370752248),
#              ('service_z', -0.74009710066),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.62272475498),
#              ('parent_area_id', 3)])
# OrderedDict([('area_id', 31),
#              ('area_name', 'Rest of Qld'),
#              ('pop_z_density', -0.930362795927),
#              ('dwelling_z_density', -0.829305214796),
#              ('service_z', -0.660288081362),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.84784297688),
#              ('parent_area_id', 3)])
# OrderedDict([('area_id', 4),
#              ('area_name', 'South Australia'),
#              ('pop_z_density', -0.763768609602),
#              ('dwelling_z_density', -0.59320258174),
#              ('service_z', -0.74009710066),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.5249551768),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 40),
#              ('area_name', 'Greater Adelaide'),
#              ('pop_z_density', -0.542726917417),
#              ('dwelling_z_density', -0.379601170634),
#              ('service_z', -0.651737115008),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.00195208786),
#              ('parent_area_id', 4)])
# OrderedDict([('area_id', 41),
#              ('area_name', 'Rest of SA'),
#              ('pop_z_density', -0.586689737307),
#              ('dwelling_z_density', -0.449370755864),
#              ('service_z', 0.10929889044),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.35464848753),
#              ('parent_area_id', 4)])
# OrderedDict([('area_id', 5),
#              ('area_name', 'Western Australia'),
#              ('pop_z_density', -0.750109760715),
#              ('dwelling_z_density', -0.628845125408),
#              ('service_z', -0.170032677103),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.97687444802),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 50),
#              ('area_name', 'Greater Perth'),
#              ('pop_z_density', -0.830197006923),
#              ('dwelling_z_density', -0.735071439073),
#              ('service_z', -0.426561667704),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.4197169985),
#              ('parent_area_id', 5)])
# OrderedDict([('area_id', 51),
#              ('area_name', 'Rest of WA'),
#              ('pop_z_density', -0.803090349712),
#              ('dwelling_z_density', -0.694322124748),
#              ('service_z', -0.415160379232),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.34045973849),
#              ('parent_area_id', 5)])
# OrderedDict([('area_id', 6),
#              ('area_name', 'Tasmania'),
#              ('pop_z_density', -0.586234154344),
#              ('dwelling_z_density', -0.51369606997),
#              ('service_z', -0.54627519665),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.07409230576),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 60),
#              ('area_name', 'Greater Hobart'),
#              ('pop_z_density', -0.327952993314),
#              ('dwelling_z_density', -0.199113441591),
#              ('service_z', -0.398058446526),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.35301176623),
#              ('parent_area_id', 6)])
# OrderedDict([('area_id', 61),
#              ('area_name', 'Rest of Tasmania'),
#              ('pop_z_density', -0.910046991542),
#              ('dwelling_z_density', -0.788151563473),
#              ('service_z', -0.774300966073),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.90038640589),
#              ('parent_area_id', 6)])
# OrderedDict([('area_id', 7),
#              ('area_name', 'Northern Territory'),
#              ('pop_z_density', -0.723687873199),
#              ('dwelling_z_density', -0.513713293302),
#              ('service_z', -0.728695812188),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.39398386349),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 70),
#              ('area_name', 'Greater Darwin'),
#              ('pop_z_density', -0.872317259915),
#              ('dwelling_z_density', -0.751285197883),
#              ('service_z', -0.44366360041),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.49515294301),
#              ('parent_area_id', 7)])
# OrderedDict([('area_id', 71),
#              ('area_name', 'Rest of NT'),
#              ('pop_z_density', -0.351767681391),
#              ('dwelling_z_density', -0.15730587939),
#              ('service_z', -0.369555225348),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.30651567093),
#              ('parent_area_id', 7)])
# OrderedDict([('area_id', 8),
#              ('area_name', 'Australian Capital Territory'),
#              ('pop_z_density', -1.11271505228),
#              ('dwelling_z_density', -1.00276472239),
#              ('service_z', -0.757199033366),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.30056569283),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 80),
#              ('area_name', 'Australian Capital Territory'),
#              ('pop_z_density', -0.997438945475),
#              ('dwelling_z_density', -0.855017733092),
#              ('service_z', -0.683090658304),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.96343422167),
#              ('parent_area_id', 8)])
# OrderedDict([('area_id', 9),
#              ('area_name', 'Other Territories'),
#              ('pop_z_density', -1.09989446932),
#              ('dwelling_z_density', -0.991733027977),
#              ('service_z', -0.623233893831),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.14274827592),
#              ('parent_area_id', 0)])
# OrderedDict([('area_id', 90),
#              ('area_name', 'Other Territories'),
#              ('pop_z_density', -0.871369006291),
#              ('dwelling_z_density', -0.711450370561),
#              ('service_z', -0.771450643955),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.7821569056),
#              ('parent_area_id', 9)])
# OrderedDict([('area_id', 102),
#              ('area_name', 'Central Coast'),
#              ('pop_z_density', -0.692484337598),
#              ('dwelling_z_density', -0.602762220602),
#              ('service_z', -0.184284287692),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.90741773069),
#              ('parent_area_id', 10)])
# OrderedDict([('area_id', 10201),
#              ('area_name', 'Gosford'),
#              ('pop_z_density', -0.750925591674),
#              ('dwelling_z_density', -0.621253864403),
#              ('service_z', -0.457915210999),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.25798155187),
#              ('parent_area_id', 102)])
# OrderedDict([('area_id', 102011028),
#              ('area_name', 'Avoca Beach - Copacabana'),
#              ('pop_z_density', -1.04155834321),
#              ('dwelling_z_density', -0.941904625227),
#              ('service_z', -0.398058446526),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.80940829976),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011029),
#              ('area_name', 'Box Head - MacMasters Beach'),
#              ('pop_z_density', -0.971120241724),
#              ('dwelling_z_density', -0.877127705069),
#              ('service_z', -0.452214566764),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.72834939835),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011030),
#              ('area_name', 'Calga - Kulnura'),
#              ('pop_z_density', -0.885452412249),
#              ('dwelling_z_density', -0.770655200614),
#              ('service_z', -0.475017143706),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.55901164137),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011031),
#              ('area_name', 'Erina - Green Point'),
#              ('pop_z_density', 0.00171117887229),
#              ('dwelling_z_density', -0.0549913114033),
#              ('service_z', 0.154904044324),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.326262973004),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011032),
#              ('area_name', 'Gosford - Springfield'),
#              ('pop_z_density', -0.37184145843),
#              ('dwelling_z_density', -0.402193596372),
#              ('service_z', 1.63137090134),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 0.429448961736),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011033),
#              ('area_name', 'Kariong'),
#              ('pop_z_density', -0.77562588265),
#              ('dwelling_z_density', -0.711660819943),
#              ('service_z', -0.563377129357),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.47855071675),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011034),
#              ('area_name', 'Kincumber - Picketts Valley'),
#              ('pop_z_density', -0.471657818211),
#              ('dwelling_z_density', -0.434762563196),
#              ('service_z', -0.158631388632),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.49293865484),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011035),
#              ('area_name', 'Narara'),
#              ('pop_z_density', -0.382577422183),
#              ('dwelling_z_density', -0.326000866008),
#              ('service_z', 0.0522924480839),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.0841727249),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011036),
#              ('area_name', 'Niagara Park - Lisarow'),
#              ('pop_z_density', -0.0705685417821),
#              ('dwelling_z_density', -0.0987153275326),
#              ('service_z', -0.654587437126),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.25175819124),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011037),
#              ('area_name', 'Point Clare - Koolewong'),
#              ('pop_z_density', -0.422410387607),
#              ('dwelling_z_density', -0.395496411288),
#              ('service_z', -0.0588701145096),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.3046637982),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011038),
#              ('area_name', 'Saratoga - Davistown'),
#              ('pop_z_density', -0.195810528046),
#              ('dwelling_z_density', -0.157610765939),
#              ('service_z', -0.124427523219),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.905735702002),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011039),
#              ('area_name', 'Terrigal - North Avoca'),
#              ('pop_z_density', 0.134327715208),
#              ('dwelling_z_density', 0.00883800880819),
#              ('service_z', -0.626084215948),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.91080537673),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011040),
#              ('area_name', 'Umina - Booker Bay - Patonga'),
#              ('pop_z_density', -0.21475116085),
#              ('dwelling_z_density', -0.262099968854),
#              ('service_z', 0.012387938435),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.892350076066),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011041),
#              ('area_name', 'Wamberal - Forresters Beach'),
#              ('pop_z_density', -0.21692302413),
#              ('dwelling_z_density', -0.279705545716),
#              ('service_z', 0.112149212557),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.812366242086),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011042),
#              ('area_name', 'Woy Woy - Blackwall'),
#              ('pop_z_density', -1.09430882958),
#              ('dwelling_z_density', -0.986504829759),
#              ('service_z', 0.656560737054),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.85213980708),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 102011043),
#              ('area_name', 'Wyoming'),
#              ('pop_z_density', -1.10588954754),
#              ('dwelling_z_density', -0.995971591279),
#              ('service_z', -0.557676485122),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.08742450874),
#              ('parent_area_id', 10201)])
# OrderedDict([('area_id', 10202),
#              ('area_name', 'Wyong'),
#              ('pop_z_density', -1.11609947498),
#              ('dwelling_z_density', -1.00580683366),
#              ('service_z', -0.768600321837),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.31839351527),
#              ('parent_area_id', 102)])
# OrderedDict([('area_id', 102021044),
#              ('area_name', 'Bateau Bay - Killarney Vale'),
#              ('pop_z_density', -1.09080178587),
#              ('dwelling_z_density', -0.980885813715),
#              ('service_z', -0.118726878983),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.61830136336),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021045),
#              ('area_name', 'Blue Haven - San Remo'),
#              ('pop_z_density', -1.06500322946),
#              ('dwelling_z_density', -0.958563768639),
#              ('service_z', -0.378106191701),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.288129838908),
#              ('walkability_score', -2.77051086842),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021046),
#              ('area_name', 'Budgewoi - Buff Point - Halekulani'),
#              ('pop_z_density', -0.856933014348),
#              ('dwelling_z_density', -0.820342455602),
#              ('service_z', 0.274617573271),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.83054478148),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021047),
#              ('area_name', 'Chittaway Bay - Tumbi Umbi'),
#              ('pop_z_density', -0.262417480561),
#              ('dwelling_z_density', -0.207522100589),
#              ('service_z', 0.337324659862),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.560501806085),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021048),
#              ('area_name', 'Gorokan - Kanwal - Charmhaven'),
#              ('pop_z_density', -0.136299323476),
#              ('dwelling_z_density', -0.165881163134),
#              ('service_z', -0.512071331237),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.24213870264),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021049),
#              ('area_name', 'Jilliby - Yarramalong'),
#              ('pop_z_density', -0.184085148803),
#              ('dwelling_z_density', -0.251927907318),
#              ('service_z', -0.378106191701),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.24200613262),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021050),
#              ('area_name', 'Lake Munmorah - Mannering Park'),
#              ('pop_z_density', -0.282219911852),
#              ('dwelling_z_density', -0.15488731676),
#              ('service_z', -0.0845230135696),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.949517126979),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021051),
#              ('area_name', 'Ourimbah - Fountaindale'),
#              ('pop_z_density', -0.252934615774),
#              ('dwelling_z_density', -0.309391685582),
#              ('service_z', 0.0237892269061),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.966423959247),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021052),
#              ('area_name', 'Summerland Point - Gwandalan'),
#              ('pop_z_density', 0.351964222567),
#              ('dwelling_z_density', 0.0615030335903),
#              ('service_z', -0.614682927477),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.629102556118),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021053),
#              ('area_name', 'The Entrance'),
#              ('pop_z_density', 0.255795359463),
#              ('dwelling_z_density', 0.118865429963),
#              ('service_z', -0.497819720648),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.55104581602),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021054),
#              ('area_name', 'Toukley - Norah Head'),
#              ('pop_z_density', 0.130058218907),
#              ('dwelling_z_density', 0.0501387203569),
#              ('service_z', -0.170032677103),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.417722622636),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021055),
#              ('area_name', 'Tuggerah - Kangy Angy'),
#              ('pop_z_density', 0.221424333442),
#              ('dwelling_z_density', -0.0413027306046),
#              ('service_z', 0.414283357042),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 0.166518075082),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021056),
#              ('area_name', 'Warnervale - Wadalba'),
#              ('pop_z_density', -1.01257351085),
#              ('dwelling_z_density', -0.928913584432),
#              ('service_z', -0.295446850286),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.66482083037),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 102021057),
#              ('area_name', 'Wyong'),
#              ('pop_z_density', 0.455474059507),
#              ('dwelling_z_density', -0.643560337486),
#              ('service_z', -0.720144845835),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.33611800861),
#              ('parent_area_id', 10202)])
# OrderedDict([('area_id', 103),
#              ('area_name', 'Central West'),
#              ('pop_z_density', 0.0599174923995),
#              ('dwelling_z_density', -0.557414832734),
#              ('service_z', -0.292596528168),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.2179807533),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 104),
#              ('area_name', 'Coffs Harbour - Grafton'),
#              ('pop_z_density', 0.0682283028917),
#              ('dwelling_z_density', -0.0228856471219),
#              ('service_z', -0.697342268893),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.07988649792),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 105),
#              ('area_name', 'Far West and Orana'),
#              ('pop_z_density', -0.474712132768),
#              ('dwelling_z_density', -0.441504720329),
#              ('service_z', -0.668839047715),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.01294278561),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 106),
#              ('area_name', 'Hunter Valley exc Newcastle'),
#              ('pop_z_density', 0.200027330372),
#              ('dwelling_z_density', 0.0260338187178),
#              ('service_z', -0.551975840886),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.753801576593),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 107),
#              ('area_name', 'Illawarra'),
#              ('pop_z_density', -0.372276528351),
#              ('dwelling_z_density', -0.345072666085),
#              ('service_z', -0.663138403479),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.80837448271),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 108),
#              ('area_name', 'Mid North Coast'),
#              ('pop_z_density', -0.0800491793416),
#              ('dwelling_z_density', -0.242518703866),
#              ('service_z', -0.221338475223),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.971793243228),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 109),
#              ('area_name', 'Murray'),
#              ('pop_z_density', -1.11608813141),
#              ('dwelling_z_density', -1.00610272258),
#              ('service_z', -0.811355153604),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.36143289239),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 110),
#              ('area_name', 'New England and North West'),
#              ('pop_z_density', -0.545351532136),
#              ('dwelling_z_density', -0.569146652998),
#              ('service_z', -0.312548782992),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.85493385292),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 111),
#              ('area_name', 'Newcastle and Lake Macquarie'),
#              ('pop_z_density', -1.11420790315),
#              ('dwelling_z_density', -1.00630846842),
#              ('service_z', -0.797103543015),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.34550679938),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 112),
#              ('area_name', 'Richmond - Tweed'),
#              ('pop_z_density', 0.181140204057),
#              ('dwelling_z_density', -0.0212734969775),
#              ('service_z', -0.389507480172),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.65752765789),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 113),
#              ('area_name', 'Riverina'),
#              ('pop_z_density', 0.557281760201),
#              ('dwelling_z_density', 0.66328518883),
#              ('service_z', 0.323073049273),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.11575311351),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 114),
#              ('area_name', 'Southern Highlands and Shoalhaven'),
#              ('pop_z_density', 0.362047012771),
#              ('dwelling_z_density', 0.346129486792),
#              ('service_z', -0.326800393581),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.0465107788151),
#              ('parent_area_id', 11)])
# OrderedDict([('area_id', 115),
#              ('area_name', 'Sydney - Baulkham Hills and Hawkesbury'),
#              ('pop_z_density', -1.11563325086),
#              ('dwelling_z_density', -1.00630846842),
#              ('service_z', -0.854109985371),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.40393858945),
#              ('parent_area_id', 10)])
# OrderedDict([('area_id', 11501),
#              ('area_name', 'Baulkham Hills'),
#              ('pop_z_density', -1.10794282143),
#              ('dwelling_z_density', -1.00630846842),
#              ('service_z', -0.885463528667),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.42760170332),
#              ('parent_area_id', 115)])
# OrderedDict([('area_id', 115011290),
#              ('area_name', 'Baulkham Hills (East)'),
#              ('pop_z_density', 0.734390416923),
#              ('dwelling_z_density', 0.674221468772),
#              ('service_z', 0.984347780599),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.9650727815),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011291),
#              ('area_name', 'Baulkham Hills (West) - Bella Vista'),
#              ('pop_z_density', 1.62978606829),
#              ('dwelling_z_density', 1.07421604205),
#              ('service_z', 0.505493664811),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 2.78160889035),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011294),
#              ('area_name', 'Glenhaven'),
#              ('pop_z_density', -0.279619058483),
#              ('dwelling_z_density', -0.430542078504),
#              ('service_z', -0.312548782992),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.45059680478),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011296),
#              ('area_name', 'West Pennant Hills'),
#              ('pop_z_density', 4.40582587465),
#              ('dwelling_z_density', 4.76170489346),
#              ('service_z', 1.18387032884),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 9.92351421216),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011553),
#              ('area_name', 'Castle Hill - Central'),
#              ('pop_z_density', 0.456204101155),
#              ('dwelling_z_density', 0.27242870436),
#              ('service_z', 0.984347780599),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.28509370132),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011554),
#              ('area_name', 'Castle Hill - East'),
#              ('pop_z_density', 0.477484127844),
#              ('dwelling_z_density', 0.151436092072),
#              ('service_z', -0.0332172154495),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 0.167816119669),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011555),
#              ('area_name', 'Castle Hill - North'),
#              ('pop_z_density', 2.45931486744),
#              ('dwelling_z_density', 1.77690041168),
#              ('service_z', 0.582452361991),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 4.39078075631),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011556),
#              ('area_name', 'Castle Hill - South'),
#              ('pop_z_density', 2.07299805519),
#              ('dwelling_z_density', 0.948743205995),
#              ('service_z', 1.52020833874),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 4.11406271513),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011557),
#              ('area_name', 'Castle Hill - West'),
#              ('pop_z_density', 5.10475103262),
#              ('dwelling_z_density', 6.56879641418),
#              ('service_z', 1.03565357872),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 12.2813141407),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011558),
#              ('area_name', 'Cherrybrook'),
#              ('pop_z_density', 5.04128815353),
#              ('dwelling_z_density', 5.43041808081),
#              ('service_z', 1.15821742978),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 11.2020367793),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 115011559),
#              ('area_name', 'Kellyville'),
#              ('pop_z_density', 3.38461344158),
#              ('dwelling_z_density', 3.21520361035),
#              ('service_z', 0.610955583169),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 6.7828857503),
#              ('parent_area_id', 11501)])
# OrderedDict([('area_id', 11502),
#              ('area_name', 'Dural - Wisemans Ferry'),
#              ('pop_z_density', 4.11647641713),
#              ('dwelling_z_density', 3.83052244517),
#              ('service_z', 1.78813861781),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 9.30725059532),
#              ('parent_area_id', 115)])
# OrderedDict([('area_id', 115021297),
#              ('area_name', 'Dural - Kenthurst - Wisemans Ferry'),
#              ('pop_z_density', 1.63725481727),
#              ('dwelling_z_density', 1.63050110206),
#              ('service_z', 13.7252876471),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 16.5651566816),
#              ('parent_area_id', 11502)])
# OrderedDict([('area_id', 115021298),
#              ('area_name', 'Galston - Laughtondale'),
#              ('pop_z_density', 2.92140155345),
#              ('dwelling_z_density', 3.41772071037),
#              ('service_z', 1.30643417991),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 7.21766955893),
#              ('parent_area_id', 11502)])
# OrderedDict([('area_id', 11503),
#              ('area_name', 'Hawkesbury'),
#              ('pop_z_density', 1.98556747013),
#              ('dwelling_z_density', 1.98560863456),
#              ('service_z', 0.556799462931),
#              ('transport_z_density', 0.883423882803),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 5.06422040535),
#              ('parent_area_id', 115)])
# OrderedDict([('area_id', 115031299),
#              ('area_name', 'Bilpin - Colo - St Albans'),
#              ('pop_z_density', 2.44159792254),
#              ('dwelling_z_density', 2.3222147366),
#              ('service_z', 0.89313747283),
#              ('transport_z_density', 0.00432202723206),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 5.31409311412),
#              ('parent_area_id', 11503)])
# OrderedDict([('area_id', 115031300),
#              ('area_name', 'Kurrajong Heights - Ebenezer'),
#              ('pop_z_density', 1.65076287606),
#              ('dwelling_z_density', 1.1857087087),
#              ('service_z', 1.89645085829),
#              ('transport_z_density', 2.36603247952),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 6.75177587749),
#              ('parent_area_id', 11503)])
# OrderedDict([('area_id', 11504),
#              ('area_name', 'Rouse Hill - McGraths Hill'),
#              ('pop_z_density', -1.11600706241),
#              ('dwelling_z_density', -1.00630846842),
#              ('service_z', -0.885463528667),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.43566594429),
#              ('parent_area_id', 115)])
# OrderedDict([('area_id', 115041301),
#              ('area_name', 'Pitt Town - McGraths Hill'),
#              ('pop_z_density', 1.06773732419),
#              ('dwelling_z_density', 1.45502465673),
#              ('service_z', 2.33255014231),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 4.42742523843),
#              ('parent_area_id', 11504)])
# OrderedDict([('area_id', 115041302),
#              ('area_name', 'Rouse Hill - Beaumont Hills'),
#              ('pop_z_density', 1.24359467676),
#              ('dwelling_z_density', 1.34408860484),
#              ('service_z', 0.0209389047883),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 2.18073530159),
#              ('parent_area_id', 11504)])
# OrderedDict([('area_id', 116),
#              ('area_name', 'Sydney - Blacktown'),
#              ('pop_z_density', 0.588194863412),
#              ('dwelling_z_density', -0.051890997843),
#              ('service_z', 0.856083285299),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 0.96450026607),
#              ('parent_area_id', 10)])
# OrderedDict([('area_id', 11601),
#              ('area_name', 'Blacktown'),
#              ('pop_z_density', -0.171725852918),
#              ('dwelling_z_density', -0.104341630654),
#              ('service_z', 0.28886918386),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.415085184509),
#              ('parent_area_id', 116)])
# OrderedDict([('area_id', 116011303),
#              ('area_name', 'Blacktown (East) - Kings Park'),
#              ('pop_z_density', 1.33751354632),
#              ('dwelling_z_density', 0.926074495237),
#              ('service_z', 0.0608434144373),
#              ('transport_z_density', 17.3166618108),
#              ('trainStation_z_density', 7.17129224597),
#              ('walkability_score', 26.8123855128),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 116011304),
#              ('area_name', 'Blacktown (North) - Marayong'),
#              ('pop_z_density', 1.63925123744),
#              ('dwelling_z_density', 1.78133494664),
#              ('service_z', 0.844681996827),
#              ('transport_z_density', -0.0261566138139),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 3.89193252201),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 116011306),
#              ('area_name', 'Doonside - Woodcroft'),
#              ('pop_z_density', -0.275279064885),
#              ('dwelling_z_density', -0.378411235522),
#              ('service_z', -0.0104146385073),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.09199182371),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 116011307),
#              ('area_name', 'Lalor Park - Kings Langley'),
#              ('pop_z_density', 1.23419900979),
#              ('dwelling_z_density', 1.0348716057),
#              ('service_z', -0.132978489572),
#              ('transport_z_density', -0.00150325888355),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.78740982195),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 116011308),
#              ('area_name', 'Seven Hills - Toongabbie'),
#              ('pop_z_density', 2.07492273345),
#              ('dwelling_z_density', 1.96670411567),
#              ('service_z', 0.077945347144),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 3.69168531146),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 116011560),
#              ('area_name', 'Blacktown (South)'),
#              ('pop_z_density', 1.08054134114),
#              ('dwelling_z_density', 0.912873866961),
#              ('service_z', -0.201386220399),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.36414210291),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 116011561),
#              ('area_name', 'Blacktown (West)'),
#              ('pop_z_density', 0.972200847111),
#              ('dwelling_z_density', 0.983832091878),
#              ('service_z', -0.275494595461),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.25265145873),
#              ('parent_area_id', 11601)])
# OrderedDict([('area_id', 11602),
#              ('area_name', 'Blacktown - North'),
#              ('pop_z_density', 0.932902956029),
#              ('dwelling_z_density', 0.803549919808),
#              ('service_z', -0.298297172403),
#              ('transport_z_density', 0.0215690432551),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.11254570161),
#              ('parent_area_id', 116)])
# OrderedDict([('area_id', 116021309),
#              ('area_name', 'Glenwood'),
#              ('pop_z_density', 2.4319347815),
#              ('dwelling_z_density', 2.66185759757),
#              ('service_z', 0.0437414817306),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 4.709646976),
#              ('parent_area_id', 11602)])
# OrderedDict([('area_id', 116021310),
#              ('area_name', 'Parklea - Kellyville Ridge'),
#              ('pop_z_density', 0.492690671565),
#              ('dwelling_z_density', 0.462203554549),
#              ('service_z', 0.511194309047),
#              ('transport_z_density', 1.34619567609),
#              ('trainStation_z_density', 5.3635601923),
#              ('walkability_score', 8.17584440355),
#              ('parent_area_id', 11602)])
# OrderedDict([('area_id', 116021312),
#              ('area_name', 'Riverstone - Marsden Park'),
#              ('pop_z_density', -0.126542656979),
#              ('dwelling_z_density', -0.221709805451),
#              ('service_z', -0.0873733356874),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.863512682914),
#              ('parent_area_id', 11602)])
# OrderedDict([('area_id', 116021562),
#              ('area_name', 'Acacia Gardens'),
#              ('pop_z_density', -1.00127183306),
#              ('dwelling_z_density', -0.948618146346),
#              ('service_z', -0.671689369833),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.04946623404),
#              ('parent_area_id', 11602)])
# OrderedDict([('area_id', 116021563),
#              ('area_name', 'Quakers Hill'),
#              ('pop_z_density', -0.6524210466),
#              ('dwelling_z_density', -0.729075477033),
#              ('service_z', -0.0218159269784),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.83119933541),
#              ('parent_area_id', 11602)])
# OrderedDict([('area_id', 11603),
#              ('area_name', 'Mount Druitt'),
#              ('pop_z_density', 0.389807592573),
#              ('dwelling_z_density', -0.0805308108409),
#              ('service_z', 0.286018861742),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.342534627493),
#              ('walkability_score', 0.857122431252),
#              ('parent_area_id', 116)])
# OrderedDict([('area_id', 116031313),
#              ('area_name', 'Bidwill - Hebersham - Emerton'),
#              ('pop_z_density', -0.108166027396),
#              ('dwelling_z_density', -0.185555703932),
#              ('service_z', -0.201386220399),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.922994836524),
#              ('parent_area_id', 11603)])
# OrderedDict([('area_id', 116031314),
#              ('area_name', 'Glendenning - Dean Park'),
#              ('pop_z_density', -0.404678462951),
#              ('dwelling_z_density', -0.416563073635),
#              ('service_z', -0.107325590512),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.35645401189),
# ...
#              ('walkability_score', -1.87322317117),
#              ('parent_area_id', 12302)])
# OrderedDict([('area_id', 123021444),
#              ('area_name', 'Rosemeadow - Glen Alpine'),
#              ('pop_z_density', 0.119045092922),
#              ('dwelling_z_density', -0.091649149623),
#              ('service_z', -0.477867465824),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 3.36496654129),
#              ('walkability_score', 2.83378717905),
#              ('parent_area_id', 12302)])
# OrderedDict([('area_id', 12303),
#              ('area_name', 'Wollondilly'),
#              ('pop_z_density', -0.321731859391),
#              ('dwelling_z_density', -0.336938175918),
#              ('service_z', -0.309698460874),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.39625538098),
#              ('parent_area_id', 123)])
# OrderedDict([('area_id', 123031445),
#              ('area_name', 'Bargo'),
#              ('pop_z_density', 0.192808786594),
#              ('dwelling_z_density', -0.0419704344816),
#              ('service_z', 0.699315568821),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.286783680289),
#              ('walkability_score', 1.05622976151),
#              ('parent_area_id', 12303)])
# OrderedDict([('area_id', 123031446),
#              ('area_name', 'Douglas Park - Appin'),
#              ('pop_z_density', 0.1745486867),
#              ('dwelling_z_density', 0.0188488262692),
#              ('service_z', -0.403759090761),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 3.25797226461),
#              ('walkability_score', 2.9669028471),
#              ('parent_area_id', 12303)])
# OrderedDict([('area_id', 123031447),
#              ('area_name', 'Picton - Tahmoor - Buxton'),
#              ('pop_z_density', 0.423154852664),
#              ('dwelling_z_density', 0.115096251732),
#              ('service_z', -0.21278750887),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 1.43110044603),
#              ('walkability_score', 1.67585620184),
#              ('parent_area_id', 12303)])
# OrderedDict([('area_id', 123031448),
#              ('area_name', 'The Oaks - Oakdale'),
#              ('pop_z_density', 0.156183293262),
#              ('dwelling_z_density', -0.00769660796658),
#              ('service_z', -0.563377129357),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.842777328859),
#              ('parent_area_id', 12303)])
# OrderedDict([('area_id', 124),
#              ('area_name', 'Sydney - Outer West and Blue Mountains'),
#              ('pop_z_density', 0.565555071958),
#              ('dwelling_z_density', 0.422646639755),
#              ('service_z', 0.0665440586728),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 0.626858885589),
#              ('parent_area_id', 10)])
# OrderedDict([('area_id', 12401),
#              ('area_name', 'Blue Mountains'),
#              ('pop_z_density', 0.525864617217),
#              ('dwelling_z_density', 0.153549335777),
#              ('service_z', -0.335351359934),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.083824291738),
#              ('parent_area_id', 124)])
# OrderedDict([('area_id', 124011449),
#              ('area_name', 'Blackheath - Megalong Valley'),
#              ('pop_z_density', -0.202952119198),
#              ('dwelling_z_density', -0.288888807267),
#              ('service_z', -0.654587437126),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.976873982666),
#              ('walkability_score', -0.25026222064),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 124011450),
#              ('area_name', 'Blaxland - Warrimoo - Lapstone'),
#              ('pop_z_density', -1.08498947763),
#              ('dwelling_z_density', -0.980500539104),
#              ('service_z', -0.600431316888),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.09380821842),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 124011451),
#              ('area_name', 'Blue Mountains - North'),
#              ('pop_z_density', -0.0257974409514),
#              ('dwelling_z_density', -0.0699832503784),
#              ('service_z', -0.272644273343),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.381130220181),
#              ('walkability_score', -0.068002584207),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 124011452),
#              ('area_name', 'Katoomba - Leura'),
#              ('pop_z_density', 0.0782326428554),
#              ('dwelling_z_density', -0.0546364245946),
#              ('service_z', -0.611832605359),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.986407457804),
#              ('walkability_score', 0.31746323099),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 124011453),
#              ('area_name', 'Lawson - Hazelbrook - Linden'),
#              ('pop_z_density', -1.11453555502),
#              ('dwelling_z_density', -1.00630846842),
#              ('service_z', -0.477867465824),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.02659837406),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 124011454),
#              ('area_name', 'Springwood - Winmalee'),
#              ('pop_z_density', -0.227745129505),
#              ('dwelling_z_density', -0.393763289013),
#              ('service_z', -0.295446850286),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 1.01469337062),
#              ('walkability_score', 0.0170302621009),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 124011455),
#              ('area_name', 'Wentworth Falls'),
#              ('pop_z_density', -0.595031577463),
#              ('dwelling_z_density', -0.559002677577),
#              ('service_z', 0.112149212557),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.0148408213471),
#              ('walkability_score', -1.13743370355),
#              ('parent_area_id', 12401)])
# OrderedDict([('area_id', 12402),
#              ('area_name', 'Blue Mountains - South'),
#              ('pop_z_density', -1.00433920837),
#              ('dwelling_z_density', -0.913909174178),
#              ('service_z', -0.309698460874),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.28183873488),
#              ('walkability_score', -2.59049341802),
#              ('parent_area_id', 124)])
# OrderedDict([('area_id', 124021456),
#              ('area_name', 'Blue Mountains - South'),
#              ('pop_z_density', 0.668344290775),
#              ('dwelling_z_density', 0.481290683189),
#              ('service_z', 0.873185218005),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 1.59493330717),
#              ('parent_area_id', 12402)])
# OrderedDict([('area_id', 12403),
#              ('area_name', 'Penrith'),
#              ('pop_z_density', 0.237051356219),
#              ('dwelling_z_density', 0.049003617538),
#              ('service_z', -0.674539691951),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 1.04179726352),
#              ('walkability_score', 0.572604705611),
#              ('parent_area_id', 124)])
# OrderedDict([('area_id', 124031457),
#              ('area_name', 'Cambridge Park'),
#              ('pop_z_density', -0.598113412001),
#              ('dwelling_z_density', -0.612373788517),
#              ('service_z', -0.152930744396),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 1.01584978648),
#              ('walkability_score', -0.428275998147),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031458),
#              ('area_name', 'Castlereagh - Cranebrook'),
#              ('pop_z_density', -0.58612928615),
#              ('dwelling_z_density', -0.468264482912),
#              ('service_z', -0.705893235246),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.18817388911),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031459),
#              ('area_name', 'Emu Plains - Leonay'),
#              ('pop_z_density', 0.0707279001181),
#              ('dwelling_z_density', 0.105253337515),
#              ('service_z', -0.246991374283),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.498897021448),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031460),
#              ('area_name', 'Glenmore Park - Regentville'),
#              ('pop_z_density', 0.0896877998753),
#              ('dwelling_z_density', 0.145867796219),
#              ('service_z', 0.516894953282),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', 0.324563664579),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031461),
#              ('area_name', 'Jamisontown - South Penrith'),
#              ('pop_z_density', -0.0661520655604),
#              ('dwelling_z_density', -0.0810876782895),
#              ('service_z', 0.191958231855),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.445770215896),
#              ('walkability_score', 0.409780864186),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031462),
#              ('area_name', 'Kingswood - Werrington'),
#              ('pop_z_density', 0.0652953620812),
#              ('dwelling_z_density', 0.0812320626132),
#              ('service_z', 0.112149212557),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -0.169210247545),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031463),
#              ('area_name', 'Mulgoa - Luddenham - Orchard Hills'),
#              ('pop_z_density', 0.0610420221588),
#              ('dwelling_z_density', -0.00215437708907),
#              ('service_z', -0.383806835937),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.836010355881),
#              ('walkability_score', 0.430383325299),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031464),
#              ('area_name', 'Penrith'),
#              ('pop_z_density', -0.73978300783),
#              ('dwelling_z_density', -0.551310072515),
#              ('service_z', 0.374378847393),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.155223814807),
#              ('walkability_score', -1.15264588747),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 124031465),
#              ('area_name', 'Warragamba - Silverdale'),
#              ('pop_z_density', -0.137240620458),
#              ('dwelling_z_density', -0.10008449657),
#              ('service_z', -0.731546134306),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.39675813613),
#              ('parent_area_id', 12403)])
# OrderedDict([('area_id', 12404),
#              ('area_name', 'Richmond - Windsor'),
#              ('pop_z_density', -0.17035975643),
#              ('dwelling_z_density', -0.193056521226),
#              ('service_z', -0.440813278292),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -1.23211644075),
#              ('parent_area_id', 124)])
# OrderedDict([('area_id', 124041466),
#              ('area_name', 'Richmond - Clarendon'),
#              ('pop_z_density', -1.02445029022),
#              ('dwelling_z_density', -0.916489726475),
#              ('service_z', -0.717294523717),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.08612142521),
#              ('parent_area_id', 12404)])
# OrderedDict([('area_id', 124041467),
#              ('area_name', 'Windsor - Bligh Park'),
#              ('pop_z_density', -0.554703493605),
#              ('dwelling_z_density', -0.481607825544),
#              ('service_z', -0.386657158055),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.312670346795),
#              ('walkability_score', -1.19100597012),
#              ('parent_area_id', 12404)])
# OrderedDict([('area_id', 124041468),
#              ('area_name', 'Yarramundi - Londonderry'),
#              ('pop_z_density', -0.869432743281),
#              ('dwelling_z_density', -0.797499174175),
#              ('service_z', -0.101624946276),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -2.19644374853),
#              ('parent_area_id', 12404)])
# OrderedDict([('area_id', 12405),
#              ('area_name', 'St Marys'),
#              ('pop_z_density', -0.171128362707),
#              ('dwelling_z_density', -0.165145279838),
#              ('service_z', -0.113026234747),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.193593651372),
#              ('walkability_score', -0.336414065636),
#              ('parent_area_id', 124)])
# OrderedDict([('area_id', 124051469),
#              ('area_name', 'Erskine Park'),
#              ('pop_z_density', -1.11650837743),
#              ('dwelling_z_density', -1.00627221165),
#              ('service_z', -0.876912562313),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', -0.347179045082),
#              ('walkability_score', -3.42758003619),
#              ('parent_area_id', 12405)])
# OrderedDict([('area_id', 124051470),
#              ('area_name', 'St Clair'),
#              ('pop_z_density', -0.0468532433875),
#              ('dwelling_z_density', 0.121308273859),
#              ('service_z', 0.206209842444),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.273785605069),
#              ('walkability_score', 0.473742638269),
#              ('parent_area_id', 12405)])
# OrderedDict([('area_id', 124051580),
#              ('area_name', 'Colyton - Oxley Park'),
#              ('pop_z_density', -0.38009073806),
#              ('dwelling_z_density', -0.291052799778),
#              ('service_z', -0.731546134306),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 0.905573520454),
#              ('walkability_score', -0.577823991406),
#              ('parent_area_id', 12405)])
# OrderedDict([('area_id', 124051581),
#              ('area_name', 'St Marys - North St Marys'),
#              ('pop_z_density', -0.669233287356),
#              ('dwelling_z_density', -0.583580445212),
#              ('service_z', -0.794253220897),
#              ('transport_z_density', -0.0807078397151),
#              ('trainStation_z_density', 1.18791208081),
#              ('walkability_score', -0.939862712371),
#              ('parent_area_id', 12405)])

# %%
import numpy
import pandas as pd
df = pd.DataFrame.from_dict(data_Index)
df.head()
# Out:
#    area_id          area_name  pop_z_density  dwelling_z_density  service_z  \
# 0        1    New South Wales      -0.667128           -0.550210  -0.432262
# 1       10     Greater Sydney      -0.986052           -0.854885  -0.469316
# 2       11        Rest of NSW      -1.114182           -1.003718  -0.569078
# 3        2           Victoria      -0.955969           -0.839998   0.288869
# 4       20  Greater Melbourne      -0.679598           -0.530387   0.673663
#
#    transport_z_density  trainStation_z_density  walkability_score  \
# 0            -0.080708               -0.347179          -2.077487
# 1            -0.080708               -0.347179          -2.738140
# 2            -0.080708               -0.347179          -3.114865
# 3            -0.080708               -0.347179          -1.934984
# 4            -0.080708               -0.347179          -0.964209
#
#    parent_area_id
# 0               0
# 1               1
# 2               1
# 3               0
# 4               2

# %%
data_Index
# Out:
# [OrderedDict([('area_id', 1),
#               ('area_name', 'New South Wales'),
#               ('pop_z_density', -0.667127523506),
#               ('dwelling_z_density', -0.550210389237),
#               ('service_z', -0.432262311939),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.07748710948),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 10),
#               ('area_name', 'Greater Sydney'),
#               ('pop_z_density', -0.986051541389),
#               ('dwelling_z_density', -0.85488511302),
#               ('service_z', -0.46931649947),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.73814003868),
#               ('parent_area_id', 1)]),
#  OrderedDict([('area_id', 11),
#               ('area_name', 'Rest of NSW'),
#               ('pop_z_density', -1.11418173746),
#               ('dwelling_z_density', -1.00371826838),
#               ('service_z', -0.569077773593),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.11486466423),
#               ('parent_area_id', 1)]),
#  OrderedDict([('area_id', 2),
#               ('area_name', 'Victoria'),
#               ('pop_z_density', -0.955968721125),
#               ('dwelling_z_density', -0.839998025172),
#               ('service_z', 0.28886918386),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.93498444723),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 20),
#               ('area_name', 'Greater Melbourne'),
#               ('pop_z_density', -0.679597875289),
#               ('dwelling_z_density', -0.530387097542),
#               ('service_z', 0.673662669761),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.964209187868),
#               ('parent_area_id', 2)]),
#  OrderedDict([('area_id', 21),
#               ('area_name', 'Rest of Victoria'),
#               ('pop_z_density', -0.816403701429),
#               ('dwelling_z_density', -0.72896421891),
#               ('service_z', -0.705893235246),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.67914804038),
#               ('parent_area_id', 2)]),
#  OrderedDict([('area_id', 3),
#               ('area_name', 'Queensland'),
#               ('pop_z_density', -0.882335144256),
#               ('dwelling_z_density', -0.803007842041),
#               ('service_z', -0.551975840886),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.66520571198),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 30),
#               ('area_name', 'Greater Brisbane'),
#               ('pop_z_density', -0.777370017272),
#               ('dwelling_z_density', -0.677370752248),
#               ('service_z', -0.74009710066),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.62272475498),
#               ('parent_area_id', 3)]),
#  OrderedDict([('area_id', 31),
#               ('area_name', 'Rest of Qld'),
#               ('pop_z_density', -0.930362795927),
#               ('dwelling_z_density', -0.829305214796),
#               ('service_z', -0.660288081362),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.84784297688),
#               ('parent_area_id', 3)]),
#  OrderedDict([('area_id', 4),
#               ('area_name', 'South Australia'),
#               ('pop_z_density', -0.763768609602),
#               ('dwelling_z_density', -0.59320258174),
#               ('service_z', -0.74009710066),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.5249551768),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 40),
#               ('area_name', 'Greater Adelaide'),
#               ('pop_z_density', -0.542726917417),
#               ('dwelling_z_density', -0.379601170634),
#               ('service_z', -0.651737115008),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.00195208786),
#               ('parent_area_id', 4)]),
#  OrderedDict([('area_id', 41),
#               ('area_name', 'Rest of SA'),
#               ('pop_z_density', -0.586689737307),
#               ('dwelling_z_density', -0.449370755864),
#               ('service_z', 0.10929889044),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.35464848753),
#               ('parent_area_id', 4)]),
#  OrderedDict([('area_id', 5),
#               ('area_name', 'Western Australia'),
#               ('pop_z_density', -0.750109760715),
#               ('dwelling_z_density', -0.628845125408),
#               ('service_z', -0.170032677103),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.97687444802),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 50),
#               ('area_name', 'Greater Perth'),
#               ('pop_z_density', -0.830197006923),
#               ('dwelling_z_density', -0.735071439073),
#               ('service_z', -0.426561667704),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.4197169985),
#               ('parent_area_id', 5)]),
#  OrderedDict([('area_id', 51),
#               ('area_name', 'Rest of WA'),
#               ('pop_z_density', -0.803090349712),
#               ('dwelling_z_density', -0.694322124748),
#               ('service_z', -0.415160379232),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.34045973849),
#               ('parent_area_id', 5)]),
#  OrderedDict([('area_id', 6),
#               ('area_name', 'Tasmania'),
#               ('pop_z_density', -0.586234154344),
#               ('dwelling_z_density', -0.51369606997),
#               ('service_z', -0.54627519665),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.07409230576),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 60),
#               ('area_name', 'Greater Hobart'),
#               ('pop_z_density', -0.327952993314),
#               ('dwelling_z_density', -0.199113441591),
#               ('service_z', -0.398058446526),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.35301176623),
#               ('parent_area_id', 6)]),
#  OrderedDict([('area_id', 61),
#               ('area_name', 'Rest of Tasmania'),
#               ('pop_z_density', -0.910046991542),
#               ('dwelling_z_density', -0.788151563473),
#               ('service_z', -0.774300966073),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.90038640589),
#               ('parent_area_id', 6)]),
#  OrderedDict([('area_id', 7),
#               ('area_name', 'Northern Territory'),
#               ('pop_z_density', -0.723687873199),
#               ('dwelling_z_density', -0.513713293302),
#               ('service_z', -0.728695812188),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.39398386349),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 70),
#               ('area_name', 'Greater Darwin'),
#               ('pop_z_density', -0.872317259915),
#               ('dwelling_z_density', -0.751285197883),
#               ('service_z', -0.44366360041),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.49515294301),
#               ('parent_area_id', 7)]),
#  OrderedDict([('area_id', 71),
#               ('area_name', 'Rest of NT'),
#               ('pop_z_density', -0.351767681391),
#               ('dwelling_z_density', -0.15730587939),
#               ('service_z', -0.369555225348),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.30651567093),
#               ('parent_area_id', 7)]),
#  OrderedDict([('area_id', 8),
#               ('area_name', 'Australian Capital Territory'),
#               ('pop_z_density', -1.11271505228),
#               ('dwelling_z_density', -1.00276472239),
#               ('service_z', -0.757199033366),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.30056569283),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 80),
#               ('area_name', 'Australian Capital Territory'),
#               ('pop_z_density', -0.997438945475),
#               ('dwelling_z_density', -0.855017733092),
#               ('service_z', -0.683090658304),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.96343422167),
#               ('parent_area_id', 8)]),
#  OrderedDict([('area_id', 9),
#               ('area_name', 'Other Territories'),
#               ('pop_z_density', -1.09989446932),
#               ('dwelling_z_density', -0.991733027977),
#               ('service_z', -0.623233893831),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.14274827592),
#               ('parent_area_id', 0)]),
#  OrderedDict([('area_id', 90),
#               ('area_name', 'Other Territories'),
#               ('pop_z_density', -0.871369006291),
#               ('dwelling_z_density', -0.711450370561),
#               ('service_z', -0.771450643955),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.7821569056),
#               ('parent_area_id', 9)]),
#  OrderedDict([('area_id', 102),
#               ('area_name', 'Central Coast'),
#               ('pop_z_density', -0.692484337598),
#               ('dwelling_z_density', -0.602762220602),
#               ('service_z', -0.184284287692),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.90741773069),
#               ('parent_area_id', 10)]),
#  OrderedDict([('area_id', 10201),
#               ('area_name', 'Gosford'),
#               ('pop_z_density', -0.750925591674),
#               ('dwelling_z_density', -0.621253864403),
#               ('service_z', -0.457915210999),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.25798155187),
#               ('parent_area_id', 102)]),
#  OrderedDict([('area_id', 102011028),
#               ('area_name', 'Avoca Beach - Copacabana'),
#               ('pop_z_density', -1.04155834321),
#               ('dwelling_z_density', -0.941904625227),
#               ('service_z', -0.398058446526),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.80940829976),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011029),
#               ('area_name', 'Box Head - MacMasters Beach'),
#               ('pop_z_density', -0.971120241724),
#               ('dwelling_z_density', -0.877127705069),
#               ('service_z', -0.452214566764),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.72834939835),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011030),
#               ('area_name', 'Calga - Kulnura'),
#               ('pop_z_density', -0.885452412249),
#               ('dwelling_z_density', -0.770655200614),
#               ('service_z', -0.475017143706),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.55901164137),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011031),
#               ('area_name', 'Erina - Green Point'),
#               ('pop_z_density', 0.00171117887229),
#               ('dwelling_z_density', -0.0549913114033),
#               ('service_z', 0.154904044324),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.326262973004),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011032),
#               ('area_name', 'Gosford - Springfield'),
#               ('pop_z_density', -0.37184145843),
#               ('dwelling_z_density', -0.402193596372),
#               ('service_z', 1.63137090134),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 0.429448961736),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011033),
#               ('area_name', 'Kariong'),
#               ('pop_z_density', -0.77562588265),
#               ('dwelling_z_density', -0.711660819943),
#               ('service_z', -0.563377129357),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.47855071675),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011034),
#               ('area_name', 'Kincumber - Picketts Valley'),
#               ('pop_z_density', -0.471657818211),
#               ('dwelling_z_density', -0.434762563196),
#               ('service_z', -0.158631388632),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.49293865484),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011035),
#               ('area_name', 'Narara'),
#               ('pop_z_density', -0.382577422183),
#               ('dwelling_z_density', -0.326000866008),
#               ('service_z', 0.0522924480839),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.0841727249),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011036),
#               ('area_name', 'Niagara Park - Lisarow'),
#               ('pop_z_density', -0.0705685417821),
#               ('dwelling_z_density', -0.0987153275326),
#               ('service_z', -0.654587437126),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.25175819124),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011037),
#               ('area_name', 'Point Clare - Koolewong'),
#               ('pop_z_density', -0.422410387607),
#               ('dwelling_z_density', -0.395496411288),
#               ('service_z', -0.0588701145096),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.3046637982),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011038),
#               ('area_name', 'Saratoga - Davistown'),
#               ('pop_z_density', -0.195810528046),
#               ('dwelling_z_density', -0.157610765939),
#               ('service_z', -0.124427523219),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.905735702002),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011039),
#               ('area_name', 'Terrigal - North Avoca'),
#               ('pop_z_density', 0.134327715208),
#               ('dwelling_z_density', 0.00883800880819),
#               ('service_z', -0.626084215948),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.91080537673),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011040),
#               ('area_name', 'Umina - Booker Bay - Patonga'),
#               ('pop_z_density', -0.21475116085),
#               ('dwelling_z_density', -0.262099968854),
#               ('service_z', 0.012387938435),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.892350076066),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011041),
#               ('area_name', 'Wamberal - Forresters Beach'),
#               ('pop_z_density', -0.21692302413),
#               ('dwelling_z_density', -0.279705545716),
#               ('service_z', 0.112149212557),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.812366242086),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011042),
#               ('area_name', 'Woy Woy - Blackwall'),
#               ('pop_z_density', -1.09430882958),
#               ('dwelling_z_density', -0.986504829759),
#               ('service_z', 0.656560737054),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.85213980708),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 102011043),
#               ('area_name', 'Wyoming'),
#               ('pop_z_density', -1.10588954754),
#               ('dwelling_z_density', -0.995971591279),
#               ('service_z', -0.557676485122),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.08742450874),
#               ('parent_area_id', 10201)]),
#  OrderedDict([('area_id', 10202),
#               ('area_name', 'Wyong'),
#               ('pop_z_density', -1.11609947498),
#               ('dwelling_z_density', -1.00580683366),
#               ('service_z', -0.768600321837),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.31839351527),
#               ('parent_area_id', 102)]),
#  OrderedDict([('area_id', 102021044),
#               ('area_name', 'Bateau Bay - Killarney Vale'),
#               ('pop_z_density', -1.09080178587),
#               ('dwelling_z_density', -0.980885813715),
#               ('service_z', -0.118726878983),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.61830136336),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021045),
#               ('area_name', 'Blue Haven - San Remo'),
#               ('pop_z_density', -1.06500322946),
#               ('dwelling_z_density', -0.958563768639),
#               ('service_z', -0.378106191701),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.288129838908),
#               ('walkability_score', -2.77051086842),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021046),
#               ('area_name', 'Budgewoi - Buff Point - Halekulani'),
#               ('pop_z_density', -0.856933014348),
#               ('dwelling_z_density', -0.820342455602),
#               ('service_z', 0.274617573271),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.83054478148),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021047),
#               ('area_name', 'Chittaway Bay - Tumbi Umbi'),
#               ('pop_z_density', -0.262417480561),
#               ('dwelling_z_density', -0.207522100589),
#               ('service_z', 0.337324659862),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.560501806085),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021048),
#               ('area_name', 'Gorokan - Kanwal - Charmhaven'),
#               ('pop_z_density', -0.136299323476),
#               ('dwelling_z_density', -0.165881163134),
#               ('service_z', -0.512071331237),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.24213870264),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021049),
#               ('area_name', 'Jilliby - Yarramalong'),
#               ('pop_z_density', -0.184085148803),
#               ('dwelling_z_density', -0.251927907318),
#               ('service_z', -0.378106191701),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.24200613262),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021050),
#               ('area_name', 'Lake Munmorah - Mannering Park'),
#               ('pop_z_density', -0.282219911852),
#               ('dwelling_z_density', -0.15488731676),
#               ('service_z', -0.0845230135696),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.949517126979),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021051),
#               ('area_name', 'Ourimbah - Fountaindale'),
#               ('pop_z_density', -0.252934615774),
#               ('dwelling_z_density', -0.309391685582),
#               ('service_z', 0.0237892269061),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.966423959247),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021052),
#               ('area_name', 'Summerland Point - Gwandalan'),
#               ('pop_z_density', 0.351964222567),
#               ('dwelling_z_density', 0.0615030335903),
#               ('service_z', -0.614682927477),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.629102556118),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021053),
#               ('area_name', 'The Entrance'),
#               ('pop_z_density', 0.255795359463),
#               ('dwelling_z_density', 0.118865429963),
#               ('service_z', -0.497819720648),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.55104581602),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021054),
#               ('area_name', 'Toukley - Norah Head'),
#               ('pop_z_density', 0.130058218907),
#               ('dwelling_z_density', 0.0501387203569),
#               ('service_z', -0.170032677103),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.417722622636),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021055),
#               ('area_name', 'Tuggerah - Kangy Angy'),
#               ('pop_z_density', 0.221424333442),
#               ('dwelling_z_density', -0.0413027306046),
#               ('service_z', 0.414283357042),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 0.166518075082),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021056),
#               ('area_name', 'Warnervale - Wadalba'),
#               ('pop_z_density', -1.01257351085),
#               ('dwelling_z_density', -0.928913584432),
#               ('service_z', -0.295446850286),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.66482083037),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 102021057),
#               ('area_name', 'Wyong'),
#               ('pop_z_density', 0.455474059507),
#               ('dwelling_z_density', -0.643560337486),
#               ('service_z', -0.720144845835),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.33611800861),
#               ('parent_area_id', 10202)]),
#  OrderedDict([('area_id', 103),
#               ('area_name', 'Central West'),
#               ('pop_z_density', 0.0599174923995),
#               ('dwelling_z_density', -0.557414832734),
#               ('service_z', -0.292596528168),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.2179807533),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 104),
#               ('area_name', 'Coffs Harbour - Grafton'),
#               ('pop_z_density', 0.0682283028917),
#               ('dwelling_z_density', -0.0228856471219),
#               ('service_z', -0.697342268893),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.07988649792),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 105),
#               ('area_name', 'Far West and Orana'),
#               ('pop_z_density', -0.474712132768),
#               ('dwelling_z_density', -0.441504720329),
#               ('service_z', -0.668839047715),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.01294278561),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 106),
#               ('area_name', 'Hunter Valley exc Newcastle'),
#               ('pop_z_density', 0.200027330372),
#               ('dwelling_z_density', 0.0260338187178),
#               ('service_z', -0.551975840886),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.753801576593),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 107),
#               ('area_name', 'Illawarra'),
#               ('pop_z_density', -0.372276528351),
#               ('dwelling_z_density', -0.345072666085),
#               ('service_z', -0.663138403479),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.80837448271),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 108),
#               ('area_name', 'Mid North Coast'),
#               ('pop_z_density', -0.0800491793416),
#               ('dwelling_z_density', -0.242518703866),
#               ('service_z', -0.221338475223),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.971793243228),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 109),
#               ('area_name', 'Murray'),
#               ('pop_z_density', -1.11608813141),
#               ('dwelling_z_density', -1.00610272258),
#               ('service_z', -0.811355153604),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.36143289239),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 110),
#               ('area_name', 'New England and North West'),
#               ('pop_z_density', -0.545351532136),
#               ('dwelling_z_density', -0.569146652998),
#               ('service_z', -0.312548782992),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.85493385292),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 111),
#               ('area_name', 'Newcastle and Lake Macquarie'),
#               ('pop_z_density', -1.11420790315),
#               ('dwelling_z_density', -1.00630846842),
#               ('service_z', -0.797103543015),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.34550679938),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 112),
#               ('area_name', 'Richmond - Tweed'),
#               ('pop_z_density', 0.181140204057),
#               ('dwelling_z_density', -0.0212734969775),
#               ('service_z', -0.389507480172),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.65752765789),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 113),
#               ('area_name', 'Riverina'),
#               ('pop_z_density', 0.557281760201),
#               ('dwelling_z_density', 0.66328518883),
#               ('service_z', 0.323073049273),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.11575311351),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 114),
#               ('area_name', 'Southern Highlands and Shoalhaven'),
#               ('pop_z_density', 0.362047012771),
#               ('dwelling_z_density', 0.346129486792),
#               ('service_z', -0.326800393581),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.0465107788151),
#               ('parent_area_id', 11)]),
#  OrderedDict([('area_id', 115),
#               ('area_name', 'Sydney - Baulkham Hills and Hawkesbury'),
#               ('pop_z_density', -1.11563325086),
#               ('dwelling_z_density', -1.00630846842),
#               ('service_z', -0.854109985371),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.40393858945),
#               ('parent_area_id', 10)]),
#  OrderedDict([('area_id', 11501),
#               ('area_name', 'Baulkham Hills'),
#               ('pop_z_density', -1.10794282143),
#               ('dwelling_z_density', -1.00630846842),
#               ('service_z', -0.885463528667),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.42760170332),
#               ('parent_area_id', 115)]),
#  OrderedDict([('area_id', 115011290),
#               ('area_name', 'Baulkham Hills (East)'),
#               ('pop_z_density', 0.734390416923),
#               ('dwelling_z_density', 0.674221468772),
#               ('service_z', 0.984347780599),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.9650727815),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011291),
#               ('area_name', 'Baulkham Hills (West) - Bella Vista'),
#               ('pop_z_density', 1.62978606829),
#               ('dwelling_z_density', 1.07421604205),
#               ('service_z', 0.505493664811),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 2.78160889035),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011294),
#               ('area_name', 'Glenhaven'),
#               ('pop_z_density', -0.279619058483),
#               ('dwelling_z_density', -0.430542078504),
#               ('service_z', -0.312548782992),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.45059680478),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011296),
#               ('area_name', 'West Pennant Hills'),
#               ('pop_z_density', 4.40582587465),
#               ('dwelling_z_density', 4.76170489346),
#               ('service_z', 1.18387032884),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 9.92351421216),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011553),
#               ('area_name', 'Castle Hill - Central'),
#               ('pop_z_density', 0.456204101155),
#               ('dwelling_z_density', 0.27242870436),
#               ('service_z', 0.984347780599),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.28509370132),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011554),
#               ('area_name', 'Castle Hill - East'),
#               ('pop_z_density', 0.477484127844),
#               ('dwelling_z_density', 0.151436092072),
#               ('service_z', -0.0332172154495),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 0.167816119669),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011555),
#               ('area_name', 'Castle Hill - North'),
#               ('pop_z_density', 2.45931486744),
#               ('dwelling_z_density', 1.77690041168),
#               ('service_z', 0.582452361991),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 4.39078075631),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011556),
#               ('area_name', 'Castle Hill - South'),
#               ('pop_z_density', 2.07299805519),
#               ('dwelling_z_density', 0.948743205995),
#               ('service_z', 1.52020833874),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 4.11406271513),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011557),
#               ('area_name', 'Castle Hill - West'),
#               ('pop_z_density', 5.10475103262),
#               ('dwelling_z_density', 6.56879641418),
#               ('service_z', 1.03565357872),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 12.2813141407),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011558),
#               ('area_name', 'Cherrybrook'),
#               ('pop_z_density', 5.04128815353),
#               ('dwelling_z_density', 5.43041808081),
#               ('service_z', 1.15821742978),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 11.2020367793),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 115011559),
#               ('area_name', 'Kellyville'),
#               ('pop_z_density', 3.38461344158),
#               ('dwelling_z_density', 3.21520361035),
#               ('service_z', 0.610955583169),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 6.7828857503),
#               ('parent_area_id', 11501)]),
#  OrderedDict([('area_id', 11502),
#               ('area_name', 'Dural - Wisemans Ferry'),
#               ('pop_z_density', 4.11647641713),
#               ('dwelling_z_density', 3.83052244517),
#               ('service_z', 1.78813861781),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 9.30725059532),
#               ('parent_area_id', 115)]),
#  OrderedDict([('area_id', 115021297),
#               ('area_name', 'Dural - Kenthurst - Wisemans Ferry'),
#               ('pop_z_density', 1.63725481727),
#               ('dwelling_z_density', 1.63050110206),
#               ('service_z', 13.7252876471),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 16.5651566816),
#               ('parent_area_id', 11502)]),
#  OrderedDict([('area_id', 115021298),
#               ('area_name', 'Galston - Laughtondale'),
#               ('pop_z_density', 2.92140155345),
#               ('dwelling_z_density', 3.41772071037),
#               ('service_z', 1.30643417991),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 7.21766955893),
#               ('parent_area_id', 11502)]),
#  OrderedDict([('area_id', 11503),
#               ('area_name', 'Hawkesbury'),
#               ('pop_z_density', 1.98556747013),
#               ('dwelling_z_density', 1.98560863456),
#               ('service_z', 0.556799462931),
#               ('transport_z_density', 0.883423882803),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 5.06422040535),
#               ('parent_area_id', 115)]),
#  OrderedDict([('area_id', 115031299),
#               ('area_name', 'Bilpin - Colo - St Albans'),
#               ('pop_z_density', 2.44159792254),
#               ('dwelling_z_density', 2.3222147366),
#               ('service_z', 0.89313747283),
#               ('transport_z_density', 0.00432202723206),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 5.31409311412),
#               ('parent_area_id', 11503)]),
#  OrderedDict([('area_id', 115031300),
#               ('area_name', 'Kurrajong Heights - Ebenezer'),
#               ('pop_z_density', 1.65076287606),
#               ('dwelling_z_density', 1.1857087087),
#               ('service_z', 1.89645085829),
#               ('transport_z_density', 2.36603247952),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 6.75177587749),
#               ('parent_area_id', 11503)]),
#  OrderedDict([('area_id', 11504),
#               ('area_name', 'Rouse Hill - McGraths Hill'),
#               ('pop_z_density', -1.11600706241),
#               ('dwelling_z_density', -1.00630846842),
#               ('service_z', -0.885463528667),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.43566594429),
#               ('parent_area_id', 115)]),
#  OrderedDict([('area_id', 115041301),
#               ('area_name', 'Pitt Town - McGraths Hill'),
#               ('pop_z_density', 1.06773732419),
#               ('dwelling_z_density', 1.45502465673),
#               ('service_z', 2.33255014231),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 4.42742523843),
#               ('parent_area_id', 11504)]),
#  OrderedDict([('area_id', 115041302),
#               ('area_name', 'Rouse Hill - Beaumont Hills'),
#               ('pop_z_density', 1.24359467676),
#               ('dwelling_z_density', 1.34408860484),
#               ('service_z', 0.0209389047883),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 2.18073530159),
#               ('parent_area_id', 11504)]),
#  OrderedDict([('area_id', 116),
#               ('area_name', 'Sydney - Blacktown'),
#               ('pop_z_density', 0.588194863412),
#               ('dwelling_z_density', -0.051890997843),
#               ('service_z', 0.856083285299),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 0.96450026607),
#               ('parent_area_id', 10)]),
#  OrderedDict([('area_id', 11601),
#               ('area_name', 'Blacktown'),
#               ('pop_z_density', -0.171725852918),
#               ('dwelling_z_density', -0.104341630654),
#               ('service_z', 0.28886918386),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.415085184509),
#               ('parent_area_id', 116)]),
#  OrderedDict([('area_id', 116011303),
#               ('area_name', 'Blacktown (East) - Kings Park'),
#               ('pop_z_density', 1.33751354632),
#               ('dwelling_z_density', 0.926074495237),
#               ('service_z', 0.0608434144373),
#               ('transport_z_density', 17.3166618108),
#               ('trainStation_z_density', 7.17129224597),
#               ('walkability_score', 26.8123855128),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 116011304),
#               ('area_name', 'Blacktown (North) - Marayong'),
#               ('pop_z_density', 1.63925123744),
#               ('dwelling_z_density', 1.78133494664),
#               ('service_z', 0.844681996827),
#               ('transport_z_density', -0.0261566138139),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 3.89193252201),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 116011306),
#               ('area_name', 'Doonside - Woodcroft'),
#               ('pop_z_density', -0.275279064885),
#               ('dwelling_z_density', -0.378411235522),
#               ('service_z', -0.0104146385073),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.09199182371),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 116011307),
#               ('area_name', 'Lalor Park - Kings Langley'),
#               ('pop_z_density', 1.23419900979),
#               ('dwelling_z_density', 1.0348716057),
#               ('service_z', -0.132978489572),
#               ('transport_z_density', -0.00150325888355),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.78740982195),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 116011308),
#               ('area_name', 'Seven Hills - Toongabbie'),
#               ('pop_z_density', 2.07492273345),
#               ('dwelling_z_density', 1.96670411567),
#               ('service_z', 0.077945347144),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 3.69168531146),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 116011560),
#               ('area_name', 'Blacktown (South)'),
#               ('pop_z_density', 1.08054134114),
#               ('dwelling_z_density', 0.912873866961),
#               ('service_z', -0.201386220399),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.36414210291),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 116011561),
#               ('area_name', 'Blacktown (West)'),
#               ('pop_z_density', 0.972200847111),
#               ('dwelling_z_density', 0.983832091878),
#               ('service_z', -0.275494595461),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.25265145873),
#               ('parent_area_id', 11601)]),
#  OrderedDict([('area_id', 11602),
#               ('area_name', 'Blacktown - North'),
#               ('pop_z_density', 0.932902956029),
#               ('dwelling_z_density', 0.803549919808),
#               ('service_z', -0.298297172403),
#               ('transport_z_density', 0.0215690432551),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.11254570161),
#               ('parent_area_id', 116)]),
#  OrderedDict([('area_id', 116021309),
#               ('area_name', 'Glenwood'),
#               ('pop_z_density', 2.4319347815),
#               ('dwelling_z_density', 2.66185759757),
#               ('service_z', 0.0437414817306),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 4.709646976),
#               ('parent_area_id', 11602)]),
#  OrderedDict([('area_id', 116021310),
#               ('area_name', 'Parklea - Kellyville Ridge'),
#               ('pop_z_density', 0.492690671565),
#               ('dwelling_z_density', 0.462203554549),
#               ('service_z', 0.511194309047),
#               ('transport_z_density', 1.34619567609),
#               ('trainStation_z_density', 5.3635601923),
#               ('walkability_score', 8.17584440355),
#               ('parent_area_id', 11602)]),
#  OrderedDict([('area_id', 116021312),
#               ('area_name', 'Riverstone - Marsden Park'),
#               ('pop_z_density', -0.126542656979),
#               ('dwelling_z_density', -0.221709805451),
#               ('service_z', -0.0873733356874),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.863512682914),
#               ('parent_area_id', 11602)]),
#  OrderedDict([('area_id', 116021562),
#               ('area_name', 'Acacia Gardens'),
#               ('pop_z_density', -1.00127183306),
#               ('dwelling_z_density', -0.948618146346),
#               ('service_z', -0.671689369833),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.04946623404),
#               ('parent_area_id', 11602)]),
#  OrderedDict([('area_id', 116021563),
#               ('area_name', 'Quakers Hill'),
#               ('pop_z_density', -0.6524210466),
#               ('dwelling_z_density', -0.729075477033),
#               ('service_z', -0.0218159269784),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.83119933541),
#               ('parent_area_id', 11602)]),
#  OrderedDict([('area_id', 11603),
#               ('area_name', 'Mount Druitt'),
#               ('pop_z_density', 0.389807592573),
#               ('dwelling_z_density', -0.0805308108409),
#               ('service_z', 0.286018861742),
# ...
#               ('trainStation_z_density', 3.36496654129),
#               ('walkability_score', 2.83378717905),
#               ('parent_area_id', 12302)]),
#  OrderedDict([('area_id', 12303),
#               ('area_name', 'Wollondilly'),
#               ('pop_z_density', -0.321731859391),
#               ('dwelling_z_density', -0.336938175918),
#               ('service_z', -0.309698460874),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.39625538098),
#               ('parent_area_id', 123)]),
#  OrderedDict([('area_id', 123031445),
#               ('area_name', 'Bargo'),
#               ('pop_z_density', 0.192808786594),
#               ('dwelling_z_density', -0.0419704344816),
#               ('service_z', 0.699315568821),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.286783680289),
#               ('walkability_score', 1.05622976151),
#               ('parent_area_id', 12303)]),
#  OrderedDict([('area_id', 123031446),
#               ('area_name', 'Douglas Park - Appin'),
#               ('pop_z_density', 0.1745486867),
#               ('dwelling_z_density', 0.0188488262692),
#               ('service_z', -0.403759090761),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 3.25797226461),
#               ('walkability_score', 2.9669028471),
#               ('parent_area_id', 12303)]),
#  OrderedDict([('area_id', 123031447),
#               ('area_name', 'Picton - Tahmoor - Buxton'),
#               ('pop_z_density', 0.423154852664),
#               ('dwelling_z_density', 0.115096251732),
#               ('service_z', -0.21278750887),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 1.43110044603),
#               ('walkability_score', 1.67585620184),
#               ('parent_area_id', 12303)]),
#  OrderedDict([('area_id', 123031448),
#               ('area_name', 'The Oaks - Oakdale'),
#               ('pop_z_density', 0.156183293262),
#               ('dwelling_z_density', -0.00769660796658),
#               ('service_z', -0.563377129357),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.842777328859),
#               ('parent_area_id', 12303)]),
#  OrderedDict([('area_id', 124),
#               ('area_name', 'Sydney - Outer West and Blue Mountains'),
#               ('pop_z_density', 0.565555071958),
#               ('dwelling_z_density', 0.422646639755),
#               ('service_z', 0.0665440586728),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 0.626858885589),
#               ('parent_area_id', 10)]),
#  OrderedDict([('area_id', 12401),
#               ('area_name', 'Blue Mountains'),
#               ('pop_z_density', 0.525864617217),
#               ('dwelling_z_density', 0.153549335777),
#               ('service_z', -0.335351359934),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.083824291738),
#               ('parent_area_id', 124)]),
#  OrderedDict([('area_id', 124011449),
#               ('area_name', 'Blackheath - Megalong Valley'),
#               ('pop_z_density', -0.202952119198),
#               ('dwelling_z_density', -0.288888807267),
#               ('service_z', -0.654587437126),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.976873982666),
#               ('walkability_score', -0.25026222064),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 124011450),
#               ('area_name', 'Blaxland - Warrimoo - Lapstone'),
#               ('pop_z_density', -1.08498947763),
#               ('dwelling_z_density', -0.980500539104),
#               ('service_z', -0.600431316888),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.09380821842),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 124011451),
#               ('area_name', 'Blue Mountains - North'),
#               ('pop_z_density', -0.0257974409514),
#               ('dwelling_z_density', -0.0699832503784),
#               ('service_z', -0.272644273343),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.381130220181),
#               ('walkability_score', -0.068002584207),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 124011452),
#               ('area_name', 'Katoomba - Leura'),
#               ('pop_z_density', 0.0782326428554),
#               ('dwelling_z_density', -0.0546364245946),
#               ('service_z', -0.611832605359),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.986407457804),
#               ('walkability_score', 0.31746323099),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 124011453),
#               ('area_name', 'Lawson - Hazelbrook - Linden'),
#               ('pop_z_density', -1.11453555502),
#               ('dwelling_z_density', -1.00630846842),
#               ('service_z', -0.477867465824),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.02659837406),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 124011454),
#               ('area_name', 'Springwood - Winmalee'),
#               ('pop_z_density', -0.227745129505),
#               ('dwelling_z_density', -0.393763289013),
#               ('service_z', -0.295446850286),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 1.01469337062),
#               ('walkability_score', 0.0170302621009),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 124011455),
#               ('area_name', 'Wentworth Falls'),
#               ('pop_z_density', -0.595031577463),
#               ('dwelling_z_density', -0.559002677577),
#               ('service_z', 0.112149212557),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.0148408213471),
#               ('walkability_score', -1.13743370355),
#               ('parent_area_id', 12401)]),
#  OrderedDict([('area_id', 12402),
#               ('area_name', 'Blue Mountains - South'),
#               ('pop_z_density', -1.00433920837),
#               ('dwelling_z_density', -0.913909174178),
#               ('service_z', -0.309698460874),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.28183873488),
#               ('walkability_score', -2.59049341802),
#               ('parent_area_id', 124)]),
#  OrderedDict([('area_id', 124021456),
#               ('area_name', 'Blue Mountains - South'),
#               ('pop_z_density', 0.668344290775),
#               ('dwelling_z_density', 0.481290683189),
#               ('service_z', 0.873185218005),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 1.59493330717),
#               ('parent_area_id', 12402)]),
#  OrderedDict([('area_id', 12403),
#               ('area_name', 'Penrith'),
#               ('pop_z_density', 0.237051356219),
#               ('dwelling_z_density', 0.049003617538),
#               ('service_z', -0.674539691951),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 1.04179726352),
#               ('walkability_score', 0.572604705611),
#               ('parent_area_id', 124)]),
#  OrderedDict([('area_id', 124031457),
#               ('area_name', 'Cambridge Park'),
#               ('pop_z_density', -0.598113412001),
#               ('dwelling_z_density', -0.612373788517),
#               ('service_z', -0.152930744396),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 1.01584978648),
#               ('walkability_score', -0.428275998147),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031458),
#               ('area_name', 'Castlereagh - Cranebrook'),
#               ('pop_z_density', -0.58612928615),
#               ('dwelling_z_density', -0.468264482912),
#               ('service_z', -0.705893235246),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.18817388911),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031459),
#               ('area_name', 'Emu Plains - Leonay'),
#               ('pop_z_density', 0.0707279001181),
#               ('dwelling_z_density', 0.105253337515),
#               ('service_z', -0.246991374283),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.498897021448),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031460),
#               ('area_name', 'Glenmore Park - Regentville'),
#               ('pop_z_density', 0.0896877998753),
#               ('dwelling_z_density', 0.145867796219),
#               ('service_z', 0.516894953282),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', 0.324563664579),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031461),
#               ('area_name', 'Jamisontown - South Penrith'),
#               ('pop_z_density', -0.0661520655604),
#               ('dwelling_z_density', -0.0810876782895),
#               ('service_z', 0.191958231855),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.445770215896),
#               ('walkability_score', 0.409780864186),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031462),
#               ('area_name', 'Kingswood - Werrington'),
#               ('pop_z_density', 0.0652953620812),
#               ('dwelling_z_density', 0.0812320626132),
#               ('service_z', 0.112149212557),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -0.169210247545),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031463),
#               ('area_name', 'Mulgoa - Luddenham - Orchard Hills'),
#               ('pop_z_density', 0.0610420221588),
#               ('dwelling_z_density', -0.00215437708907),
#               ('service_z', -0.383806835937),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.836010355881),
#               ('walkability_score', 0.430383325299),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031464),
#               ('area_name', 'Penrith'),
#               ('pop_z_density', -0.73978300783),
#               ('dwelling_z_density', -0.551310072515),
#               ('service_z', 0.374378847393),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.155223814807),
#               ('walkability_score', -1.15264588747),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 124031465),
#               ('area_name', 'Warragamba - Silverdale'),
#               ('pop_z_density', -0.137240620458),
#               ('dwelling_z_density', -0.10008449657),
#               ('service_z', -0.731546134306),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.39675813613),
#               ('parent_area_id', 12403)]),
#  OrderedDict([('area_id', 12404),
#               ('area_name', 'Richmond - Windsor'),
#               ('pop_z_density', -0.17035975643),
#               ('dwelling_z_density', -0.193056521226),
#               ('service_z', -0.440813278292),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -1.23211644075),
#               ('parent_area_id', 124)]),
#  OrderedDict([('area_id', 124041466),
#               ('area_name', 'Richmond - Clarendon'),
#               ('pop_z_density', -1.02445029022),
#               ('dwelling_z_density', -0.916489726475),
#               ('service_z', -0.717294523717),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.08612142521),
#               ('parent_area_id', 12404)]),
#  OrderedDict([('area_id', 124041467),
#               ('area_name', 'Windsor - Bligh Park'),
#               ('pop_z_density', -0.554703493605),
#               ('dwelling_z_density', -0.481607825544),
#               ('service_z', -0.386657158055),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.312670346795),
#               ('walkability_score', -1.19100597012),
#               ('parent_area_id', 12404)]),
#  OrderedDict([('area_id', 124041468),
#               ('area_name', 'Yarramundi - Londonderry'),
#               ('pop_z_density', -0.869432743281),
#               ('dwelling_z_density', -0.797499174175),
#               ('service_z', -0.101624946276),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -2.19644374853),
#               ('parent_area_id', 12404)]),
#  OrderedDict([('area_id', 12405),
#               ('area_name', 'St Marys'),
#               ('pop_z_density', -0.171128362707),
#               ('dwelling_z_density', -0.165145279838),
#               ('service_z', -0.113026234747),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.193593651372),
#               ('walkability_score', -0.336414065636),
#               ('parent_area_id', 124)]),
#  OrderedDict([('area_id', 124051469),
#               ('area_name', 'Erskine Park'),
#               ('pop_z_density', -1.11650837743),
#               ('dwelling_z_density', -1.00627221165),
#               ('service_z', -0.876912562313),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', -0.347179045082),
#               ('walkability_score', -3.42758003619),
#               ('parent_area_id', 12405)]),
#  OrderedDict([('area_id', 124051470),
#               ('area_name', 'St Clair'),
#               ('pop_z_density', -0.0468532433875),
#               ('dwelling_z_density', 0.121308273859),
#               ('service_z', 0.206209842444),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.273785605069),
#               ('walkability_score', 0.473742638269),
#               ('parent_area_id', 12405)]),
#  OrderedDict([('area_id', 124051580),
#               ('area_name', 'Colyton - Oxley Park'),
#               ('pop_z_density', -0.38009073806),
#               ('dwelling_z_density', -0.291052799778),
#               ('service_z', -0.731546134306),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 0.905573520454),
#               ('walkability_score', -0.577823991406),
#               ('parent_area_id', 12405)]),
#  OrderedDict([('area_id', 124051581),
#               ('area_name', 'St Marys - North St Marys'),
#               ('pop_z_density', -0.669233287356),
#               ('dwelling_z_density', -0.583580445212),
#               ('service_z', -0.794253220897),
#               ('transport_z_density', -0.0807078397151),
#               ('trainStation_z_density', 1.18791208081),
#               ('walkability_score', -0.939862712371),
#               ('parent_area_id', 12405)])]

# %%
p_list = list(df.groupby(['parent_area_id']))
mean_list = df.groupby(['parent_area_id'])['walkability_score'].agg('mean')
dic = {'parent_area_id': p_list, 'mean': mean_list}

# %%
dic = {}

for r in data_Index:
    dic[r['parent_area_id']]= r['walkability_score'] + dic.get(r['parent_area_id'], 0)
     
length = len(dic.keys())
for key in dic:
    dic[key]=dic[key]/length
        
key_list = []
mean_list = []
for k in dic:
    key_list.append(k)
    mean_list.append(dic[k])
    
dic_new = {'parent_id': key_list, 'mean': mean_list}

import pandas as pd
df2 = pd.DataFrame(dic_new)
df2.head()
# Out:
#        mean  parent_id
# 0 -0.374422          0
# 1 -0.099203          1
# 2 -0.061752          2
# 3 -0.092721          3
# 4 -0.056892          4

# %%
df2.sort_values(by= ["mean"], ascending=0)
# Out:
#         mean  parent_id
# 16  0.905824      11501
# 21  0.639122      11601
# 27  0.526328      11703
# 17  0.403099      11502
# 25  0.309074      11701
# 29  0.287188      11801
# 18  0.204506      11503
# 15  0.127258        115
# 22  0.121039      11602
# 19  0.112003      11504
# 32  0.098290      11901
# 50  0.084752      12301
# 52  0.082309      12303
# 48  0.074777      12203
# 28  0.068514        118
# 43  0.048392      12103
# 10  0.037885         10
# 34  0.030233      11903
# 46  0.027524      12201
# 55  0.027033      12402
# 20  0.026349        116
# 33  0.025480      11902
# 31  0.023399        119
# 44  0.022213      12104
# 45  0.016381        122
# 24  0.009187        117
# 26  0.005459      11702
# 23 -0.000897      11603
# 30 -0.001591      11802
# 49 -0.014506        123
# 47 -0.032230      12202
# 9  -0.047155          9
# 8  -0.050228          8
# 4  -0.056892          4
# 2  -0.061752          2
# 53 -0.062208        124
# 7  -0.064435          7
# 6  -0.072091          6
# 58 -0.075789      12405
# 56 -0.079140      12403
# 5  -0.080681          5
# 3  -0.092721          3
# 11 -0.094515        102
# 1  -0.099203          1
# 57 -0.109722      12404
# 40 -0.117607        121
# 54 -0.122739      12401
# 36 -0.131541        120
# 38 -0.151175      12002
# 37 -0.157442      12001
# 42 -0.175425      12102
# 41 -0.196900      12101
# 51 -0.223761      12302
# 35 -0.233578      11904
# 14 -0.271101         11
# 13 -0.298512      10202
# 0  -0.374422          0
# 39 -0.385753      12003
# 12 -0.407907      10201

# %%
df2.sort_values(by= ["mean"], ascending=0)
# Out:
#         mean  parent_id
# 16  0.905824      11501
# 21  0.639122      11601
# 27  0.526328      11703
# 17  0.403099      11502
# 25  0.309074      11701
# 29  0.287188      11801
# 18  0.204506      11503
# 15  0.127258        115
# 22  0.121039      11602
# 19  0.112003      11504
# 32  0.098290      11901
# 50  0.084752      12301
# 52  0.082309      12303
# 48  0.074777      12203
# 28  0.068514        118
# 43  0.048392      12103
# 10  0.037885         10
# 34  0.030233      11903
# 46  0.027524      12201
# 55  0.027033      12402
# 20  0.026349        116
# 33  0.025480      11902
# 31  0.023399        119
# 44  0.022213      12104
# 45  0.016381        122
# 24  0.009187        117
# 26  0.005459      11702
# 23 -0.000897      11603
# 30 -0.001591      11802
# 49 -0.014506        123
# 47 -0.032230      12202
# 9  -0.047155          9
# 8  -0.050228          8
# 4  -0.056892          4
# 2  -0.061752          2
# 53 -0.062208        124
# 7  -0.064435          7
# 6  -0.072091          6
# 58 -0.075789      12405
# 56 -0.079140      12403
# 5  -0.080681          5
# 3  -0.092721          3
# 11 -0.094515        102
# 1  -0.099203          1
# 57 -0.109722      12404
# 40 -0.117607        121
# 54 -0.122739      12401
# 36 -0.131541        120
# 38 -0.151175      12002
# 37 -0.157442      12001
# 42 -0.175425      12102
# 41 -0.196900      12101
# 51 -0.223761      12302
# 35 -0.233578      11904
# 14 -0.271101         11
# 13 -0.298512      10202
# 0  -0.374422          0
# 39 -0.385753      12003
# 12 -0.407907      10201
